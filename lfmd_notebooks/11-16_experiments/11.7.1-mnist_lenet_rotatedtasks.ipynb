# %%
# %load_ext autoreload
# %autoreload 2
import sys
import torch
import pickle
import pandas as pd
from torch import nn
import numpy as np
# sys.path.append('..')
# sys.path.append('/system/user/beck/pwbeck/projects/regularization/ml_utilities')
from pathlib import Path
from omegaconf import OmegaConf
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from tueplots.constants.color import palettes
###
from ml_utilities.torch_models.fc import FC
from ml_utilities.output_loader.model_loader import load_model_from_idx, load_directions_matrix_from_task_sweep, load_multiple_dir_matrices_from_sweep
from ml_utilities.output_loader.job_output import SweepResult, JobResult
from ml_utilities.output_loader.plot import plot_sweep_summary, plot_data_log_values
###
from erank.data.datasetgenerator import DatasetGenerator
from ml_utilities.data_utils import show_images
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
gpu_id = 0

# %% [markdown]
# # 11.7.1 MNIST Lenet rotatedtasks

# %%
# experiment config + output directory
output_dir = '/system/user/beck/pwbeck/projects/regularization/erank/outputs/mnist-11.7.1-lenet_rotatedtasks--221104_083629'
pretrain_dir = '/system/user/beck/pwbeck/projects/regularization/erank/outputs/mnist-11.5.0-lenet--221015_122552'

# %% [markdown]
# ## A. Pretrain run

# %%
jobpr = JobResult(pretrain_dir)
jobpr.is_successful_job, jobpr.override_hpparams, jobpr.data_log_sources, jobpr.progress_measure, jobpr.best_model_idx
# Out:
# (True, {}, ['train_step', 'train', 'val'], 'step', 430)

# %%
jobpr.get_summary()
# Out:
#                                    best_step  best_val_score  seed
# mnist-11.5.0-lenet--221015_122552        430         0.96075     0

# %%
prdf = jobpr.get_data_log('train')
prdf
# Out:
#    log_step  epoch  train_step  loss_CrossEntropyLoss  Accuracy  \
# 0       413      1         375               0.299769  0.911146
# 1       541      2         490               0.121593  0.962636
#
#    time_last_train_epoch_in_s
# 0                    0.000000
# 1                  106.144387

# %%
prdf = jobpr.get_data_log(['train_step', 'val'])
prdf
# Out:
#      log_step  epoch  train_step  train_step-loss_CrossEntropyLoss  \
# 490         0      0           0                               NaN
# 0           1      1           0                          2.313010
# 1           2      1           1                          2.201852
# 2           3      1           2                          2.098251
# 3           4      1           3                          1.988275
# ..        ...    ...         ...                               ...
# 486       536      2         486                          0.164481
# 487       537      2         487                          0.137834
# 488       538      2         488                          0.083491
# 489       539      2         489                          0.075387
# 539       540      2         490                               NaN
#
#      train_step-Accuracy  train_step-weight_norm  val-loss_CrossEntropyLoss  \
# 490                  NaN                     NaN                   2.307779
# 0               0.101562               11.707621                        NaN
# 1               0.429688               11.726831                        NaN
# 2               0.468750               11.752336                        NaN
# 3               0.539062               11.783297                        NaN
# ..                   ...                     ...                        ...
# 486             0.945312               16.577518                        NaN
# 487             0.953125               16.582777                        NaN
# 488             0.976562               16.588509                        NaN
# 489             0.976562               16.595190                        NaN
# 539                  NaN                     NaN                   0.137353
#
#      val-Accuracy  val-time_last_val_epoch_in_s
# 490      0.100833                      0.000000
# 0             NaN                           NaN
# 1             NaN                           NaN
# 2             NaN                           NaN
# 3             NaN                           NaN
# ..            ...                           ...
# 486           NaN                           NaN
# 487           NaN                           NaN
# 488           NaN                           NaN
# 489           NaN                           NaN
# 539      0.959833                      2.632582
#
# [540 rows x 9 columns]

# %%
# plot learning curve
f = plot_data_log_values(prdf, x_axis='train_step', y_axis_left=['train_step-Accuracy', 'val-Accuracy'])

# %%
alpha = 0.5
ls = '--'
style_dict = {
    'train_step-loss_CrossEntropyLoss': {
        'label': 'Training'
    },
    'val-loss_CrossEntropyLoss': {
        'label': 'Validation'
    },
    'train_step-Accuracy': {
        'label': '',
        'alpha': alpha,
        'ls': ls
    },
    'val-Accuracy': {
        'label': '',
        'alpha': alpha,
        'ls': ls
    }
}
from ml_utilities.plot import tol_colors
cset = tol_colors.tol_cset('medium-contrast')
with plt.rc_context({'axes.prop_cycle': mpl.cycler('color', cset), 'font.size': 12}):
    f = plot_data_log_values(prdf,
                             x_axis='train_step',
                             y_axis_left=['train_step-loss_CrossEntropyLoss', 'val-loss_CrossEntropyLoss'],
                             y_axis_right=['train_step-Accuracy', 'val-Accuracy'],
                             y_label_left='Cross Entropy Loss',
                             y_label_right='Accuracy',
                             x_label='Gradient Steps',
                             style_dict=style_dict,
                             ylim=(-0.15,2.62),
                             figsize=(2 * 12 * 1 / 2.54, 1.5 * 8 * 1 / 2.54))
    f.axes[0].vlines(x=[0, 100], ymin=0, ymax=2.5, colors=[cset.light_red, cset.light_red], lw=3, alpha=0.9)

# %%
f.savefig("pretraining_lenet_mnist_w_marker.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ## B. Sweep

# %% [markdown]
# ### Load Sweep

# %%
sweepr = SweepResult(output_dir)
sweepr.sweep_params#, sweepr.get_failed_jobs()
# Out:
# 100%|██████████| 2520/2520 [00:10<00:00, 241.06it/s]
# (['trainer.init_model_step', 'data.dataset_kwargs.rotation_angle'], [])

# %%
print(OmegaConf.to_yaml(sweepr.sweep_dict))
# Out:
# type: grid
# axes:
# - parameter: trainer.init_model_step
#   vals:
#   - 0
#   - 5
#   - 10
#   - 20
#   - 50
#   - 100
#   - 480
# - parameter: data.dataset_kwargs.rotation_angle
#   vals: linspace(0,180,360,endpoint=True)

# %%
init_model_step_vals = [0, 5, 10, 100, 480] #[0, 5, 10, 20, 50, 100, 480]
row_sel_train_steps = [0, 5, 10, 30, 100, 500]

# %%
sdf = sweepr.get_summary(log_source='val', row_sel=('train_step', row_sel_train_steps), col_sel=['Accuracy'])
sdf
# Out:
# 100%|██████████| 2520/2520 [00:54<00:00, 46.10it/s]
#                                                     best_step  best_val_score  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1095        0.975250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1910        0.978167
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1955        0.979500
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1540        0.977750
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1910        0.978417
# ...                                                       ...             ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1980        0.979250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1990        0.977917
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1980        0.978000
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1690        0.977083
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1695        0.977917
#
#                                                     Accuracy-train_step-0  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.100833
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.101167
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.100417
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.100417
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.099333
# ...                                                                   ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.131500
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.131750
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.131417
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.131500
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.131000
#
#                                                     Accuracy-train_step-5  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.635333
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.634083
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.629083
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.617333
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.628000
# ...                                                                   ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.356167
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.355583
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.355750
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.354833
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.354917
#
#                                                     Accuracy-train_step-10  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.692917
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.699917
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.711333
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.712000
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.707083
# ...                                                                    ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.537917
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.538833
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.538583
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.538167
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.537250
#
#                                                     Accuracy-train_step-30  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.851917
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.853000
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.851250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.853000
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.850833
# ...                                                                    ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.818500
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.819167
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.819667
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.820083
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.819500
#
#                                                     Accuracy-train_step-100  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.913250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.912750
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.913250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.912750
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.909250
# ...                                                                     ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.907917
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.906000
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.907167
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.907500
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.907833
#
#                                                     Accuracy-train_step-500  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.960667
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.960250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.961833
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.963083
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.963250
# ...                                                                     ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.960667
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.960750
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.960667
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.960500
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.962167
#
#                                                     trainer.init_model_step  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                        0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                        0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                        0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                        0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                        0
# ...                                                                     ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                       50
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                       50
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                       50
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                       50
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                       50
#
#                                                     data.dataset_kwargs.rotation_angle  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                            0.000000
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                            0.501393
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                            1.002786
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                            1.504178
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                           10.027855
# ...                                                                                ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                           97.771588
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                           98.272981
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                           98.774373
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                           99.275766
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                           99.777159
#
#                                                     seed
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# ...                                                  ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
#
# [2520 rows x 11 columns]

# %% [markdown]
# ### Adaptation for different model steps

# %%
f = plot_sweep_summary(sdf, x_axis='data.dataset_kwargs.rotation_angle', y_axis='best_val_score', compare_parameter='trainer.init_model_step', compare_parameter_val_selection=init_model_step_vals)
f = plot_sweep_summary(sdf, x_axis='data.dataset_kwargs.rotation_angle', y_axis='best_step', compare_parameter='trainer.init_model_step', compare_parameter_val_selection=init_model_step_vals)

# %%
train_steps = row_sel_train_steps
for train_step in row_sel_train_steps:
    f = plot_sweep_summary(sdf, x_axis='data.dataset_kwargs.rotation_angle', y_axis=f'Accuracy-train_step-{train_step}', compare_parameter='trainer.init_model_step', compare_parameter_val_selection=init_model_step_vals, ylim=(0,1.0))

# %%
# fig.savefig(f'11_6_mnist_conv4_rotatedtasks_erankplot.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Plots for Presentation: rot_angle vs. Accuracy for different training length

# %%
init_model_step_vals = [0, 100] #[0, 5, 10, 20, 50, 100, 480]
row_sel_train_steps = [0, 5, 10, 30, 100, 500]
sdf2 = sweepr.get_summary(log_source='val', row_sel=('train_step', row_sel_train_steps), col_sel=['Accuracy'])
sdf2
# Out:
# 100%|██████████| 2520/2520 [00:54<00:00, 46.07it/s]
#                                                     best_step  best_val_score  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1095        0.975250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1910        0.978167
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1955        0.979500
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1540        0.977750
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1910        0.978417
# ...                                                       ...             ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1980        0.979250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1990        0.977917
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1980        0.978000
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1690        0.977083
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1695        0.977917
#
#                                                     Accuracy-train_step-0  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.100833
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.101167
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.100417
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.100417
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.099333
# ...                                                                   ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.131500
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.131750
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.131417
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.131500
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.131000
#
#                                                     Accuracy-train_step-5  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.635333
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.634083
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.629083
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.617333
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.628000
# ...                                                                   ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.356167
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.355583
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.355750
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.354833
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.354917
#
#                                                     Accuracy-train_step-10  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.692917
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.699917
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.711333
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.712000
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.707083
# ...                                                                    ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.537917
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.538833
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.538583
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.538167
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.537250
#
#                                                     Accuracy-train_step-30  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.851917
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.853000
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.851250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.853000
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.850833
# ...                                                                    ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.818500
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.819167
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.819667
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.820083
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.819500
#
#                                                     Accuracy-train_step-100  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.913250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.912750
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.913250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.912750
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.909250
# ...                                                                     ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.907917
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.906000
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.907167
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.907500
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.907833
#
#                                                     Accuracy-train_step-500  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.960667
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.960250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.961833
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.963083
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.963250
# ...                                                                     ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.960667
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.960750
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.960667
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.960500
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.962167
#
#                                                     trainer.init_model_step  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                        0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                        0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                        0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                        0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                        0
# ...                                                                     ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                       50
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                       50
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                       50
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                       50
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                       50
#
#                                                     data.dataset_kwargs.rotation_angle  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                            0.000000
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                            0.501393
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                            1.002786
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                            1.504178
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                           10.027855
# ...                                                                                ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                           97.771588
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                           98.272981
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                           98.774373
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                           99.275766
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                           99.777159
#
#                                                     seed
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# ...                                                  ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
#
# [2520 rows x 11 columns]

# %%
sdf2[sdf2['trainer.init_model_step']==100].sort_values(by='data.dataset_kwargs.rotation_angle')
# Out:
#                                                     best_step  best_val_score  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1900        0.978333
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1715        0.978417
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1880        0.978667
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1980        0.978500
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1880        0.978500
# ...                                                       ...             ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1915        0.979333
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1985        0.979667
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1965        0.979500
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1990        0.979500
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...       1990        0.979250
#
#                                                     Accuracy-train_step-0  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.913250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.913667
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.913750
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.912250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.910917
# ...                                                                   ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.228000
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.227250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.226417
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.226583
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.226333
#
#                                                     Accuracy-train_step-5  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.905917
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.905833
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.905083
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.906250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.906167
# ...                                                                   ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.347833
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.348083
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.348667
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.348250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...               0.348583
#
#                                                     Accuracy-train_step-10  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.893083
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.893417
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.894667
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.893667
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.895000
# ...                                                                    ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.525667
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.528417
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.529417
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.530667
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.531750
#
#                                                     Accuracy-train_step-30  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.922583
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.923083
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.922583
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.923333
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.922500
# ...                                                                    ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.786500
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.788917
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.789000
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.789833
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                0.789917
#
#                                                     Accuracy-train_step-100  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.929750
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.929750
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.930833
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.929250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.930500
# ...                                                                     ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.915833
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.917083
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.917250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.917833
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.917500
#
#                                                     Accuracy-train_step-500  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.966750
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.966250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.966417
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.967083
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.966417
# ...                                                                     ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.964583
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.964917
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.965250
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.964833
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                 0.964917
#
#                                                     trainer.init_model_step  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                      100
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                      100
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                      100
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                      100
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                      100
# ...                                                                     ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                      100
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                      100
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                      100
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                      100
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                      100
#
#                                                     data.dataset_kwargs.rotation_angle  \
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                            0.000000
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                            0.501393
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                            1.002786
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                            1.504178
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                            2.005571
# ...                                                                                ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                          177.994429
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                          178.495822
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                          178.997214
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                          179.498607
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...                          180.000000
#
#                                                     seed
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# ...                                                  ...
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
# mnist-11.7.1-lenet_rotatedtasks--init_model_ste...     0
#
# [360 rows x 11 columns]

# %%
from ml_utilities.plot import color_palettes
color_palettes.grad_tol_medium_contrast_lightred_darkblue
# Out:
# array(['994455', '903e62', '813c70', '6a3d7c', '494184', '004488'],
#       dtype='<U6')

# %%
y_axis = [f'Accuracy-train_step-{train_step}' for train_step in row_sel_train_steps]
pretrain_steps = [0,100]
labels = [f'init_model_step={ps}#{y_ax}' for ps in pretrain_steps for y_ax in y_axis ]
style_dict = {
    'init_model_step=0#Accuracy-train_step-0': dict(label='0'),
    'init_model_step=0#Accuracy-train_step-5': dict(label='5'),
    'init_model_step=0#Accuracy-train_step-10': dict(label='10'),
    'init_model_step=0#Accuracy-train_step-30': dict(label='30'),
    'init_model_step=0#Accuracy-train_step-100': dict(label='100'),
    'init_model_step=0#Accuracy-train_step-500': dict(label='500'),
    'init_model_step=100#Accuracy-train_step-0': dict(label=''),
    'init_model_step=100#Accuracy-train_step-5': dict(label=''),
    'init_model_step=100#Accuracy-train_step-10': dict(label=''),
    'init_model_step=100#Accuracy-train_step-30': dict(label=''),
    'init_model_step=100#Accuracy-train_step-100': dict(label=''),
    'init_model_step=100#Accuracy-train_step-500': dict(label=''),
}

# %%
# create plot for rotated experiment
with mpl.rc_context({
        'axes.prop_cycle': mpl.cycler('color', color_palettes.grad_tol_medium_contrast_lightred_darkblue),
        'font.size': 12,
        'lines.linewidth': 1.75
}):
    fig, ax = plt.subplots(1, 2, figsize=(2.5 * 12 * 1 / 2.54, 1.5 * 8 * 1 / 2.54), sharey=True, sharex=True)
    fig.tight_layout()
    ax = ax.tolist()
    f = plot_sweep_summary(sdf2,
                           ax=ax[0],
                           x_axis='data.dataset_kwargs.rotation_angle',
                           y_axis=y_axis,
                           compare_parameter='trainer.init_model_step',
                           compare_parameter_val_selection=[0],
                           y_label='Accuracy',
                           x_label='Rotation angle',
                           style_dict=style_dict,
                           legend_args={},
                           ylim=(0, 1.0))
    f = plot_sweep_summary(sdf2,
                           ax=ax[1],
                           x_axis='data.dataset_kwargs.rotation_angle',
                           y_axis=y_axis,
                           compare_parameter='trainer.init_model_step',
                           compare_parameter_val_selection=[100],
                           y_label=' ',
                           style_dict=style_dict,
                           x_label='Rotation angle',
                           legend_args={},
                           ylim=(0, 1.0))
    handles, labels = ax[0].get_legend_handles_labels()
    ax[0].legend(handles[::-1], labels[::-1], frameon=False, title='Gradient Steps', loc='center left', bbox_to_anchor=(2.08, 0.5), ncol=1)

# %%
fig.savefig("trainfromscratch_vs_finetuning_lenet_rotatedmnist.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ## C. Dataset

# %%
def show_rotated_dataset(rotation_angle, n_images=9, n_cols=3):
    data_cfg = f"""
data:
  dataset: rotatedvision
  dataset_kwargs:
    data_root_path: /system/user/beck/pwbeck/data
    dataset: mnist
    rotation_angle: {rotation_angle}
  dataset_split:
    train_val_split: 0.8
"""
    data_cfg = OmegaConf.create(data_cfg)
    data_cfg = data_cfg.data
    dataset_generator = DatasetGenerator(dataset=data_cfg.dataset,
                                     dataset_kwargs=data_cfg.dataset_kwargs,
                                     dataset_split=data_cfg.dataset_split)
    dataset_generator.generate_dataset()
    train_set, val_set = dataset_generator.train_split, dataset_generator.val_split
    show_images(train_set, n_images, n_cols, cmap='gray', shuffle=False, select_idxes=[21, 23, 1, 3, 2, 7, 4, 8, 0], fname=f'mnist_{rotation_angle}.png')

# %%
show_rotated_dataset(0)

# %%
show_rotated_dataset(35.0)

# %%
rotation_angle = 0.0
data_cfg = f"""
data:
  dataset: rotatedvision
  dataset_kwargs:
    data_root_path: /system/user/beck/pwbeck/data
    dataset: mnist
    rotation_angle: {rotation_angle}
  dataset_split:
    train_val_split: 0.8
"""
data_cfg = OmegaConf.create(data_cfg)
data_cfg = data_cfg.data
dataset_generator = DatasetGenerator(dataset=data_cfg.dataset,
                                     dataset_kwargs=data_cfg.dataset_kwargs,
                                     dataset_split=data_cfg.dataset_split)
dataset_generator.generate_dataset()
train_set, val_set = dataset_generator.train_split, dataset_generator.val_split

# %%
# Find indexes such that every digit is in list
labels_to_find = np.arange(1,10).tolist()
labels_remaining = len(labels_to_find)

label_idx_dict = {label: None for label in labels_to_find}

idx = 0
while labels_remaining > 0:
    label = train_set[idx][1]
    if label in label_idx_dict and label_idx_dict[label] is None:
        label_idx_dict[label] = idx
        labels_remaining -= 1
    idx += 1
print(label_idx_dict)
print(list(label_idx_dict.values()))
# Out:
# {1: 21, 2: 23, 3: 1, 4: 3, 5: 2, 6: 7, 7: 4, 8: 8, 9: 0}
# [21, 23, 1, 3, 2, 7, 4, 8, 0]
