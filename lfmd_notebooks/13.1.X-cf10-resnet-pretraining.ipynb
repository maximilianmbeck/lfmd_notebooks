# %%
# %load_ext autoreload
# %autoreload 2
import torch
import numpy as np
import pandas as pd
from omegaconf import OmegaConf
from pathlib import Path
from pprint import pprint
# plotting
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# mycode
from repo import REPO
from ml_utilities.output_loader.job_output import SweepResult, JobResult
from ml_utilities.output_loader import create_job_output_loader
from ml_utilities.output_loader.plot import plot_sweep_summary, plot_data_log_values
from erank.mode_connectivity.instability_analysis import InstabilityAnalyzer
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 13.1 CIFAR 10 ResNet Pretraining
#
# With this notebook I start the pretraining runs on CIFAR10, which are then used for later finetuning for the stability analysis.
# I also start the finetuning runs here

# %%
config_yaml = """
run_config:
  exec_type: parallel
  hostname: dragonfly
  gpu_ids: [0,1]
  runs_per_gpu: 2
  wandb:
    init:
      tags:
      - ${config.experiment_data.experiment_tag}_exps
      - run_handler
      notes: null
      group: ${config.experiment_data.experiment_tag}
      job_type: run_handler

seeds: [11,17,31]

sweep:
  type: grid
  axes: 
  - parameter: data.dataset_transforms.enable_transforms
    vals: [True, False]
  # - parameter: trainer.optimizer_scheduler.optimizer_kwargs.lr
  #   vals: [0.1, 0.075, 0.05, 0.025]
  # - parameter: trainer.optimizer_scheduler.optimizer_kwargs.weight_decay
  #   vals: [0.0, 0.001, 0.005]
  # - parameter: trainer.batch_size
  #   vals: [64, 256, 512]
    
start_num: 1

config:
  experiment_data:
    entity: jkuiml-fsl
    project_name: tflearning
    experiment_tag: '13.1'
    experiment_type: startnum_${start_num}
    experiment_name: cifar10-${config.experiment_data.experiment_tag}.${start_num}-resnet-B-pretrain
    experiment_dir: null
    experiment_notes: 
    job_name: null
    seed: 0
    hostname: null
    gpu_id: 0
  wandb:
    init:
      tags:
      - ${config.experiment_data.experiment_tag}_exps
      notes: ${config.experiment_data.experiment_notes}
      group: ${config.experiment_data.experiment_tag}
      job_type: ${config.experiment_data.experiment_type}
    watch:
      log: null
      log_freq:

  model:
    model_cfg: resnet20-cifar10-B
    # name: resnet
    # model_kwargs:
    #   in_channels: 3
    #   act_fn: relu
    #   residual_option: B
    #   input_layer_config:
    #     kernel_size: 3
    #     out_channels: 16
    #     bias: false
    #     batch_norm: true
    #     stride: 1
    #     padding: 1
    #   resnet_blocks_config:
    #     - out_channels: 16
    #       num_residual_blocks: 3
    #     - out_channels: 32
    #       num_residual_blocks: 3
    #     - out_channels: 64
    #       num_residual_blocks: 3
    #   linear_output_units:
    #     - 10
    init_model: null

  trainer:
    training_setup: supervised
    n_steps: 64e3
    log_train_step_every: 1
    log_additional_train_step_every_multiplier: 1
    log_additional_logs: true
    val_every: 500
    save_every: 1000
    early_stopping_patience: 64e3
    batch_size: 128
    optimizer_scheduler:
      optimizer_name: SGD
      optimizer_kwargs:
        lr: 0.01 #0.1
        momentum: 0.9
        weight_decay: 0.0001
      lr_scheduler_name: MultiStepLR
      lr_scheduler_kwargs:
        milestones: [32e3, 48e3]
        gamma: 0.1

    loss: crossentropy
    metrics:
    - Accuracy
    num_workers: 4
    verbose: false
  data:
    dataset: cifar10
    dataset_kwargs:
      data_root_path: /system/user/beck/pwbeck/data
    dataset_split:
      train_val_split: 0.9
      # restrict_n_samples_train_task: 100
    dataset_transforms:
      image_transforms:
      - RandomHorizontalFlip
      - RandomCrop:
          size: 32
          padding: 4
      tensor_transforms: 
      joint_tensor_transforms: 
      enable_transforms: True
"""
cfg = OmegaConf.create(config_yaml)

# %%
# run_command = REPO.create_experiment(cfg, override=False)
# print(run_command)

# %% [markdown]
# ### Sweep result

# %%
sweepr = REPO.get_output_loader(cfg)
print(sweepr)
# Out:
# Exp. Tag(start_num): 13.1(1)
# Exp. Name: cifar10-13.1.1-resnet-B-pretrain
# Training setup: supervised
# Model name: resnet20-cifar10-B
# Dataset name: cifar10
# Sweep type: grid
#   data.dataset_transforms.enable_transforms: [True, False]
# Seeds: [11, 17, 31]
# Num. jobs: 6
# Config updated: 2023-01-12 16:36:01
# Sweep started:  2023-01-12 16:39:14

# %%
failed_jobs = sweepr.get_failed_jobs()
failed_jobs # No failed jobs
# Out:
# Collecting failed jobs: 100%|██████████| 6/6 [00:00<00:00, 52.42it/s]
# ([], {})

# %%
pprint(sweepr.available_log_columns)
# Out:
# {'_common_cols': ['epoch', 'train_step', 'log_step'],
#  'train': ['lr',
#            'loss_CrossEntropyLoss',
#            'time_last_train_epoch_in_s',
#            'Accuracy'],
#  'train_step': ['lr', 'weight_norm', 'loss_CrossEntropyLoss', 'Accuracy'],
#  'val': ['time_last_val_epoch_in_s', 'loss_CrossEntropyLoss', 'Accuracy']}

# %%
sw_summary = sweepr.get_summary()
sw_summary
# Out:
# Collecting summaries: 100%|██████████| 6/6 [00:00<00:00, 3261.09it/s]
#                                                     best_step  best_val_score  \
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...      16000          0.7922
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...      47500          0.7978
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...      25500          0.7980
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...      58500          0.8748
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...      34500          0.8770
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...      62000          0.8822
#
#                                                     data.dataset_transforms.enable_transforms  \
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...                                      False
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...                                      False
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...                                      False
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...                                       True
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...                                       True
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...                                       True
#
#                                                     seed
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...    11
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...    17
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...    31
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...    11
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...    17
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...    31

# %% [markdown]
# # 13.5 CIFAR10 Resnet enable_transforms=True finetuning

# %%
# get a single pretraining job
df, jobs = sweepr.query_jobs({'seed':31, 'data.dataset_transforms.enable_transforms': True})
df
# Out:
#                                                     best_step  best_val_score  \
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...      62000          0.8822
#
#                                                     data.dataset_transforms.enable_transforms  \
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...                                       True
#
#                                                     seed
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...    31

# %%
pretrain_job_et = jobs[0]
pretrain_job_et
# Out:
# JobResult(cifar10-13.1.1-resnet-B-pretrain--enable_transforms-1-seed-31--230112_163938)

# %%
print(pretrain_job_et.directory)
# Out:
# /system/user/publicwork/beck/projects/regularization/erank/outputs/cifar10-13.1.1-resnet-B-pretrain--230112_163914/outputs/cifar10-13.1.1-resnet-B-pretrain--enable_transforms-1-seed-31--230112_163938

# %%
# determine pretrain indices, remaining training time and lr schedule milestones
pretrain_idxes = np.array(pretrain_job_et.available_model_checkpoint_indices[::6])
pretrain_idxes.tolist()
# Out:
# [0, 6000, 12000, 18000, 24000, 30000, 36000, 42000, 48000, 54000, 60000]

# %%
total_steps = cfg.config.trainer.n_steps
remaining_training_steps = total_steps - np.array(pretrain_idxes)
remaining_training_steps.astype(int).tolist()
# Out:
# [64000, 58000, 52000, 46000, 40000, 34000, 28000, 22000, 16000, 10000, 4000]

# %%
config_yaml = """
run_config:
  exec_type: parallel
  hostname: dragonfly
  gpu_ids: [0,1]
  runs_per_gpu: 2
  wandb:
    init:
      tags:
      - ${config.experiment_data.experiment_tag}_exps
      - run_handler
      notes: null
      group: ${config.experiment_data.experiment_tag}
      job_type: run_handler

seeds: [21,22]

sweep:
  type: line
  axes: 
  - parameter: trainer.n_steps # remaining steps to train
    vals: [64000, 58000, 52000, 46000, 40000, 34000, 28000, 22000, 16000, 10000, 4000]
  - parameter: model.pretrain_idx
    vals: [0, 6000, 12000, 18000, 24000, 30000, 36000, 42000, 48000, 54000, 60000]

    
start_num: 0

config:
  experiment_data:
    entity: jkuiml-fsl
    project_name: tflearning
    experiment_tag: '13.5'
    experiment_type: startnum_${start_num}
    experiment_name: cifar10-${config.experiment_data.experiment_tag}.${start_num}-resnet-B-finetune-enableT
    experiment_dir: null
    experiment_notes: 
    job_name: null
    seed: 0
    hostname: null
    gpu_id: 0
  wandb:
    init:
      tags:
      - ${config.experiment_data.experiment_tag}_exps
      notes: ${config.experiment_data.experiment_notes}
      group: ${config.experiment_data.experiment_tag}
      job_type: ${config.experiment_data.experiment_type}
    watch:
      log: null
      log_freq:

  model:
    model_cfg: resnet20-cifar10-B
    # name: resnet
    # model_kwargs:
    #   in_channels: 3
    #   act_fn: relu
    #   residual_option: B
    #   input_layer_config:
    #     kernel_size: 3
    #     out_channels: 16
    #     bias: false
    #     batch_norm: true
    #     stride: 1
    #     padding: 1
    #   resnet_blocks_config:
    #     - out_channels: 16
    #       num_residual_blocks: 3
    #     - out_channels: 32
    #       num_residual_blocks: 3
    #     - out_channels: 64
    #       num_residual_blocks: 3
    #   linear_output_units:
    #     - 10
    pretrain_idx: 0
    init_model: /system/user/publicwork/beck/projects/regularization/erank/outputs/cifar10-13.1.1-resnet-B-pretrain--230112_163914/outputs/cifar10-13.1.1-resnet-B-pretrain--enable_transforms-1-seed-31--230112_163938/model_step_${config.model.pretrain_idx}.p


  trainer:
    training_setup: supervised
    n_steps: 64e3
    log_train_step_every: 1
    log_additional_train_step_every_multiplier: 1
    log_additional_logs: true
    val_every: 500
    save_every: 1000
    early_stopping_patience: 64e3
    batch_size: 128
    optimizer_scheduler:
      optimizer_name: SGD
      optimizer_kwargs:
        lr: 0.01 #0.1
        momentum: 0.9
        weight_decay: 0.0001
      lr_scheduler_name: MultiStepLR
      lr_scheduler_kwargs:
        milestones: [32e3, 48e3]
        gamma: 0.1

    loss: crossentropy
    metrics:
    - Accuracy
    num_workers: 4
    verbose: false
  data:
    dataset: cifar10
    dataset_kwargs:
      data_root_path: /system/user/beck/pwbeck/data
    dataset_split:
      train_val_split: 0.9
      # restrict_n_samples_train_task: 100
    dataset_transforms:
      image_transforms:
      - RandomHorizontalFlip
      - RandomCrop:
          size: 32
          padding: 4
      tensor_transforms: 
      joint_tensor_transforms: 
      enable_transforms: True
"""
cfg = OmegaConf.create(config_yaml)

# %%
# run_command = REPO.create_experiment(cfg, override=False)
# print(run_command)

# %%
finetunesw5 = REPO.get_output_loader(cfg)
print(finetunesw5)
# Out:
# Exp. Tag(start_num): 13.5(0)
# Exp. Name: cifar10-13.5.0-resnet-B-finetune-enableT
# Training setup: supervised
# Model name: resnet20-cifar10-B
# Dataset name: cifar10
# Sweep type: line
#   trainer.n_steps: [64000, 58000, 52000, 46000, 40000, 34000, 28000, 22000, 16000, 10000, 4000]
#   model.pretrain_idx: [0, 6000, 12000, 18000, 24000, 30000, 36000, 42000, 48000, 54000, 60000]
# Seeds: [21, 22]
# Num. jobs: 22
# Config updated: 2023-01-13 10:33:01
# Sweep started:  2023-01-13 10:33:37

# %%
fdir = finetunesw5.directory
print(fdir)
# Out:
# /system/user/publicwork/beck/projects/regularization/erank/outputs/cifar10-13.5.0-resnet-B-finetune-enableT--230113_103337

# %%
insta5 = InstabilityAnalyzer.reload(finetunesw5.directory, instability_folder_suffix='0')
# Out:
# Collecting failed jobs: 100%|██████████| 22/22 [00:14<00:00,  1.54it/s]

# %%
insta5.combined_results_dfs['datasets']
# Out:
# datasets                                                                                                                    val  \
# score                                                                                                      interpolation_scores
# alpha                                                                                                                      0.00
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (54000, 35500)               0.5424
#                                                                                             (64000, 64000)               0.5422
#                6000             cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 48500)               0.5482
#                                                                                             (58000, 58000)               0.5482
#                12000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (46000, 33500)               0.4566
#                                                                                             (52000, 52000)               0.4572
#                18000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (33500, 40500)               0.4042
#                                                                                             (46000, 46000)               0.4036
#                24000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34500, 40000)               0.3980
#                                                                                             (40000, 40000)               0.3976
#                30000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 33500)               0.4490
#                                                                                             (34000, 34000)               0.4484
#                36000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (24500, 23000)               0.4174
#                                                                                             (28000, 28000)               0.4180
#                42000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (9000, 19500)                0.4346
#                                                                                             (22000, 22000)               0.4340
#                48000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)                       0.4834
#                                                                                             (16000, 16000)               0.4836
#                54000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)                       0.4914
#                                                                                             (10000, 10000)               0.4922
#                60000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)                       0.4912
#                                                                                             (4000, 4000)                 0.4916
#
# datasets                                                                                                            \
# score
# alpha                                                                                                         0.25
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (54000, 35500)  0.4742
#                                                                                             (64000, 64000)  0.4742
#                6000             cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 48500)  0.5684
#                                                                                             (58000, 58000)  0.5686
#                12000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (46000, 33500)  0.4814
#                                                                                             (52000, 52000)  0.4810
#                18000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (33500, 40500)  0.4452
#                                                                                             (46000, 46000)  0.4456
#                24000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34500, 40000)  0.4404
#                                                                                             (40000, 40000)  0.4408
#                30000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 33500)  0.4704
#                                                                                             (34000, 34000)  0.4706
#                36000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (24500, 23000)  0.4394
#                                                                                             (28000, 28000)  0.4402
#                42000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (9000, 19500)   0.4466
#                                                                                             (22000, 22000)  0.4460
#                48000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.4836
#                                                                                             (16000, 16000)  0.4840
#                54000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.4920
#                                                                                             (10000, 10000)  0.4922
#                60000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.4916
#                                                                                             (4000, 4000)    0.4918
#
# datasets                                                                                                            \
# score
# alpha                                                                                                         0.50
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (54000, 35500)  0.1824
#                                                                                             (64000, 64000)  0.1822
#                6000             cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 48500)  0.5596
#                                                                                             (58000, 58000)  0.5608
#                12000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (46000, 33500)  0.4922
#                                                                                             (52000, 52000)  0.4920
#                18000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (33500, 40500)  0.4696
#                                                                                             (46000, 46000)  0.4694
#                24000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34500, 40000)  0.4722
#                                                                                             (40000, 40000)  0.4714
#                30000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 33500)  0.4780
#                                                                                             (34000, 34000)  0.4778
#                36000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (24500, 23000)  0.4466
#                                                                                             (28000, 28000)  0.4470
#                42000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (9000, 19500)   0.4410
#                                                                                             (22000, 22000)  0.4418
#                48000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.4834
#                                                                                             (16000, 16000)  0.4836
#                54000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.4920
#                                                                                             (10000, 10000)  0.4926
#                60000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.4918
#                                                                                             (4000, 4000)    0.4916
#
# datasets                                                                                                            \
# score
# alpha                                                                                                         0.75
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (54000, 35500)  0.2796
#                                                                                             (64000, 64000)  0.2800
#                6000             cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 48500)  0.5318
#                                                                                             (58000, 58000)  0.5312
#                12000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (46000, 33500)  0.4878
#                                                                                             (52000, 52000)  0.4876
#                18000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (33500, 40500)  0.4694
#                                                                                             (46000, 46000)  0.4704
#                24000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34500, 40000)  0.4876
#                                                                                             (40000, 40000)  0.4870
#                30000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 33500)  0.4758
#                                                                                             (34000, 34000)  0.4766
#                36000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (24500, 23000)  0.4440
#                                                                                             (28000, 28000)  0.4440
#                42000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (9000, 19500)   0.4110
#                                                                                             (22000, 22000)  0.4104
#                48000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.4836
#                                                                                             (16000, 16000)  0.4840
#                54000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.4926
#                                                                                             (10000, 10000)  0.4918
#                60000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.4916
#                                                                                             (4000, 4000)    0.4920
#
# datasets                                                                                                            \
# score
# alpha                                                                                                         1.00
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (54000, 35500)  0.3300
#                                                                                             (64000, 64000)  0.3302
#                6000             cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 48500)  0.4760
#                                                                                             (58000, 58000)  0.4752
#                12000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (46000, 33500)  0.4658
#                                                                                             (52000, 52000)  0.4654
#                18000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (33500, 40500)  0.4566
#                                                                                             (46000, 46000)  0.4572
#                24000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34500, 40000)  0.4762
#                                                                                             (40000, 40000)  0.4764
#                30000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 33500)  0.4596
#                                                                                             (34000, 34000)  0.4602
#                36000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (24500, 23000)  0.4178
#                                                                                             (28000, 28000)  0.4172
#                42000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (9000, 19500)   0.3736
#                                                                                             (22000, 22000)  0.3738
#                48000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.4836
#                                                                                             (16000, 16000)  0.4838
#                54000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.4920
#                                                                                             (10000, 10000)  0.4922
#                60000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.4918
#                                                                                             (4000, 4000)    0.4920
#
# datasets                                                                                                                \
# score                                                                                                      instability
# alpha                                                                                                              NaN
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (54000, 35500)     -0.2538
#                                                                                             (64000, 64000)     -0.2540
#                6000             cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 48500)     -0.0361
#                                                                                             (58000, 58000)     -0.0365
#                12000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (46000, 33500)     -0.0046
#                                                                                             (52000, 52000)     -0.0041
#                18000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (33500, 40500)     -0.0262
#                                                                                             (46000, 46000)     -0.0268
#                24000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34500, 40000)     -0.0391
#                                                                                             (40000, 40000)     -0.0394
#                30000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 33500)     -0.0053
#                                                                                             (34000, 34000)     -0.0059
#                36000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (24500, 23000)     -0.0002
#                                                                                             (28000, 28000)     -0.0004
#                42000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (9000, 19500)      -0.0305
#                                                                                             (22000, 22000)     -0.0301
#                48000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)             -0.0001
#                                                                                             (16000, 16000)     -0.0001
#                54000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)             -0.0003
#                                                                                             (10000, 10000)     -0.0004
#                60000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)             -0.0003
#                                                                                             (4000, 4000)       -0.0002
#
# datasets                                                                                                                  train  \
# score                                                                                                      interpolation_scores
# alpha                                                                                                                      0.00
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (54000, 35500)             0.519822
#                                                                                             (64000, 64000)             0.520689
#                6000             cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 48500)             0.542667
#                                                                                             (58000, 58000)             0.544978
#                12000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (46000, 33500)             0.449089
#                                                                                             (52000, 52000)             0.450111
#                18000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (33500, 40500)             0.411378
#                                                                                             (46000, 46000)             0.415200
#                24000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34500, 40000)             0.384000
#                                                                                             (40000, 40000)             0.386133
#                30000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 33500)             0.381467
#                                                                                             (34000, 34000)             0.384356
#                36000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (24500, 23000)             0.314289
#                                                                                             (28000, 28000)             0.314867
#                42000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (9000, 19500)              0.394578
#                                                                                             (22000, 22000)             0.398133
#                48000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)                     0.476111
#                                                                                             (16000, 16000)             0.477778
#                54000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)                     0.489422
#                                                                                             (10000, 10000)             0.489533
#                60000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)                     0.496978
#                                                                                             (4000, 4000)               0.498422
#
# datasets                                                                                                              \
# score
# alpha                                                                                                           0.25
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (54000, 35500)  0.485711
#                                                                                             (64000, 64000)  0.487000
#                6000             cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 48500)  0.574467
#                                                                                             (58000, 58000)  0.572933
#                12000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (46000, 33500)  0.467111
#                                                                                             (52000, 52000)  0.467089
#                18000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (33500, 40500)  0.441467
#                                                                                             (46000, 46000)  0.443889
#                24000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34500, 40000)  0.414156
#                                                                                             (40000, 40000)  0.412644
#                30000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 33500)  0.405600
#                                                                                             (34000, 34000)  0.406422
#                36000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (24500, 23000)  0.329067
#                                                                                             (28000, 28000)  0.330067
#                42000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (9000, 19500)   0.385200
#                                                                                             (22000, 22000)  0.388800
#                48000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.475711
#                                                                                             (16000, 16000)  0.477333
#                54000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.490644
#                                                                                             (10000, 10000)  0.489778
#                60000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.497933
#                                                                                             (4000, 4000)    0.498578
#
# datasets                                                                                                              \
# score
# alpha                                                                                                           0.50
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (54000, 35500)  0.176089
#                                                                                             (64000, 64000)  0.173711
#                6000             cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 48500)  0.568622
#                                                                                             (58000, 58000)  0.570889
#                12000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (46000, 33500)  0.470667
#                                                                                             (52000, 52000)  0.472089
#                18000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (33500, 40500)  0.451444
#                                                                                             (46000, 46000)  0.452644
#                24000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34500, 40000)  0.422556
#                                                                                             (40000, 40000)  0.424800
#                30000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 33500)  0.419800
#                                                                                             (34000, 34000)  0.416956
#                36000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (24500, 23000)  0.335311
#                                                                                             (28000, 28000)  0.335622
#                42000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (9000, 19500)   0.363267
#                                                                                             (22000, 22000)  0.361222
#                48000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.477867
#                                                                                             (16000, 16000)  0.477978
#                54000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.488489
#                                                                                             (10000, 10000)  0.486911
#                60000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.500533
#                                                                                             (4000, 4000)    0.500178
#
# datasets                                                                                                              \
# score
# alpha                                                                                                           0.75
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (54000, 35500)  0.288178
#                                                                                             (64000, 64000)  0.287244
#                6000             cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 48500)  0.543533
#                                                                                             (58000, 58000)  0.544244
#                12000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (46000, 33500)  0.463667
#                                                                                             (52000, 52000)  0.462378
#                18000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (33500, 40500)  0.438422
#                                                                                             (46000, 46000)  0.438711
#                24000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34500, 40000)  0.420911
#                                                                                             (40000, 40000)  0.419333
#                30000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 33500)  0.419044
#                                                                                             (34000, 34000)  0.416667
#                36000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (24500, 23000)  0.326600
#                                                                                             (28000, 28000)  0.327311
#                42000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (9000, 19500)   0.319022
#                                                                                             (22000, 22000)  0.319444
#                48000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.475889
#                                                                                             (16000, 16000)  0.478222
#                54000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.490400
#                                                                                             (10000, 10000)  0.488689
#                60000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.497689
#                                                                                             (4000, 4000)    0.499022
#
# datasets                                                                                                              \
# score
# alpha                                                                                                           1.00
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (54000, 35500)  0.325400
#                                                                                             (64000, 64000)  0.327111
#                6000             cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 48500)  0.497622
#                                                                                             (58000, 58000)  0.498089
#                12000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (46000, 33500)  0.441178
#                                                                                             (52000, 52000)  0.442289
#                18000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (33500, 40500)  0.407333
#                                                                                             (46000, 46000)  0.407111
#                24000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34500, 40000)  0.401267
#                                                                                             (40000, 40000)  0.398867
#                30000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 33500)  0.403533
#                                                                                             (34000, 34000)  0.403578
#                36000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (24500, 23000)  0.307622
#                                                                                             (28000, 28000)  0.307400
#                42000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (9000, 19500)   0.267956
#                                                                                             (22000, 22000)  0.268933
#                48000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.478689
#                                                                                             (16000, 16000)  0.476911
#                54000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.488800
#                                                                                             (10000, 10000)  0.488178
#                60000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)          0.499933
#                                                                                             (4000, 4000)    0.497289
#
# datasets
# score                                                                                                      instability
# alpha                                                                                                              NaN
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (54000, 35500)   -0.246522
#                                                                                             (64000, 64000)   -0.250189
#                6000             cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 48500)   -0.022522
#                                                                                             (58000, 58000)   -0.023444
#                12000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (46000, 33500)   -0.003956
#                                                                                             (52000, 52000)   -0.003911
#                18000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (33500, 40500)   -0.002022
#                                                                                             (46000, 46000)   -0.004044
#                24000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34500, 40000)   -0.008633
#                                                                                             (40000, 40000)   -0.006367
#                30000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (34000, 33500)   -0.011033
#                                                                                             (34000, 34000)   -0.009611
#                36000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (24500, 23000)   -0.003333
#                                                                                             (28000, 28000)   -0.003733
#                42000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (9000, 19500)    -0.063311
#                                                                                             (22000, 22000)   -0.064600
#                48000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)           -0.001689
#                                                                                             (16000, 16000)   -0.000433
#                54000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)           -0.000622
#                                                                                             (10000, 10000)   -0.001944
#                60000            cifar10-13.5.0-resnet-B-finetune-enableT--n_ste... (21, 22) (0, 0)           -0.001478
#                                                                                             (4000, 4000)     -0.000567

# %% [markdown]
# # 13.6 CIFAR10 Resnet enable_transforms=False finetuning

# %%
# get a single pretraining job
df, jobs = sweepr.query_jobs({'seed':31, 'data.dataset_transforms.enable_transforms': False})
df
# Out:
#                                                     best_step  best_val_score  \
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...      25500           0.798
#
#                                                     data.dataset_transforms.enable_transforms  \
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...                                      False
#
#                                                     seed
# cifar10-13.1.1-resnet-B-pretrain--enable_transf...    31

# %%
pretrain_job_dt = jobs[0]
print(pretrain_job_dt.directory)
# Out:
# /system/user/publicwork/beck/projects/regularization/erank/outputs/cifar10-13.1.1-resnet-B-pretrain--230112_163914/outputs/cifar10-13.1.1-resnet-B-pretrain--enable_transforms-0-seed-31--230112_163941

# %%
config_yaml = """
run_config:
  exec_type: parallel
  hostname: dragonfly
  gpu_ids: [2,3]
  runs_per_gpu: 2
  wandb:
    init:
      tags:
      - ${config.experiment_data.experiment_tag}_exps
      - run_handler
      notes: null
      group: ${config.experiment_data.experiment_tag}
      job_type: run_handler

seeds: [21,22]

sweep:
  type: line
  axes: 
  - parameter: trainer.n_steps # remaining steps to train
    vals: [64000, 58000, 52000, 46000, 40000, 34000, 28000, 22000, 16000, 10000, 4000]
  - parameter: model.pretrain_idx
    vals: [0, 6000, 12000, 18000, 24000, 30000, 36000, 42000, 48000, 54000, 60000]

    
start_num: 0

config:
  experiment_data:
    entity: jkuiml-fsl
    project_name: tflearning
    experiment_tag: '13.6'
    experiment_type: startnum_${start_num}
    experiment_name: cifar10-${config.experiment_data.experiment_tag}.${start_num}-resnet-B-finetune-disableT
    experiment_dir: null
    experiment_notes: 
    job_name: null
    seed: 0
    hostname: null
    gpu_id: 0
  wandb:
    init:
      tags:
      - ${config.experiment_data.experiment_tag}_exps
      notes: ${config.experiment_data.experiment_notes}
      group: ${config.experiment_data.experiment_tag}
      job_type: ${config.experiment_data.experiment_type}
    watch:
      log: null
      log_freq:

  model:
    model_cfg: resnet20-cifar10-B
    # name: resnet
    # model_kwargs:
    #   in_channels: 3
    #   act_fn: relu
    #   residual_option: B
    #   input_layer_config:
    #     kernel_size: 3
    #     out_channels: 16
    #     bias: false
    #     batch_norm: true
    #     stride: 1
    #     padding: 1
    #   resnet_blocks_config:
    #     - out_channels: 16
    #       num_residual_blocks: 3
    #     - out_channels: 32
    #       num_residual_blocks: 3
    #     - out_channels: 64
    #       num_residual_blocks: 3
    #   linear_output_units:
    #     - 10
    pretrain_idx: 0
    init_model: /system/user/publicwork/beck/projects/regularization/erank/outputs/cifar10-13.1.1-resnet-B-pretrain--230112_163914/outputs/cifar10-13.1.1-resnet-B-pretrain--enable_transforms-0-seed-31--230112_163941/model_step_${config.model.pretrain_idx}.p


  trainer:
    training_setup: supervised
    n_steps: 64e3
    log_train_step_every: 1
    log_additional_train_step_every_multiplier: 1
    log_additional_logs: true
    val_every: 500
    save_every: 1000
    early_stopping_patience: 64e3
    batch_size: 128
    optimizer_scheduler:
      optimizer_name: SGD
      optimizer_kwargs:
        lr: 0.01 #0.1
        momentum: 0.9
        weight_decay: 0.0001
      lr_scheduler_name: MultiStepLR
      lr_scheduler_kwargs:
        milestones: [32e3, 48e3]
        gamma: 0.1

    loss: crossentropy
    metrics:
    - Accuracy
    num_workers: 4
    verbose: false
  data:
    dataset: cifar10
    dataset_kwargs:
      data_root_path: /system/user/beck/pwbeck/data
    dataset_split:
      train_val_split: 0.9
      # restrict_n_samples_train_task: 100
    dataset_transforms:
      image_transforms:
      - RandomHorizontalFlip
      - RandomCrop:
          size: 32
          padding: 4
      tensor_transforms: 
      joint_tensor_transforms: 
      enable_transforms: True
"""
cfg = OmegaConf.create(config_yaml)

# %%
# run_command = REPO.create_experiment(cfg, override=False)
# print(run_command)

# %%
finetunesw6 = REPO.get_output_loader(cfg)

# %%
print(finetunesw6.directory)
# Out:
# /system/user/publicwork/beck/projects/regularization/erank/outputs/cifar10-13.6.0-resnet-B-finetune-disableT--230113_103818

# %%
insta6 = InstabilityAnalyzer.reload(finetunesw6.directory, instability_folder_suffix='0')
# Out:
# Collecting failed jobs: 100%|██████████| 22/22 [00:13<00:00,  1.58it/s]

# %%
insta6.combined_results_dfs['datasets']
# Out:
# datasets                                                                                                                    val  \
# score                                                                                                      interpolation_scores
# alpha                                                                                                                      0.00
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (40000, 38500)               0.0984
#                                                                                             (64000, 64000)               0.0984
#                6000             cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (56500, 33000)               0.1152
#                                                                                             (58000, 58000)               0.1152
#                12000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (35000, 40500)               0.1244
#                                                                                             (52000, 52000)               0.1246
#                18000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34500, 44500)               0.1804
#                                                                                             (46000, 46000)               0.1802
#                24000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (32500, 36500)               0.2032
#                                                                                             (40000, 40000)               0.2030
#                30000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34000, 34000)               0.2228
#                                                                                             (34000, 34000)               0.2228
#                36000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (28000, 28000)               0.1964
#                                                                                             (28000, 28000)               0.1970
#                42000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 21500)               0.2622
#                                                                                             (22000, 22000)               0.2620
#                48000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 16000)               0.1824
#                                                                                             (16000, 16000)               0.1816
#                54000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (10000, 10000)               0.2618
#                                                                                             (10000, 10000)               0.2626
#                60000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (3500, 3500)                 0.2378
#                                                                                             (4000, 4000)                 0.2376
#
# datasets                                                                                                            \
# score
# alpha                                                                                                         0.25
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (40000, 38500)  0.1308
#                                                                                             (64000, 64000)  0.1308
#                6000             cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (56500, 33000)  0.1180
#                                                                                             (58000, 58000)  0.1182
#                12000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (35000, 40500)  0.1222
#                                                                                             (52000, 52000)  0.1224
#                18000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34500, 44500)  0.1784
#                                                                                             (46000, 46000)  0.1784
#                24000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (32500, 36500)  0.2076
#                                                                                             (40000, 40000)  0.2082
#                30000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34000, 34000)  0.2384
#                                                                                             (34000, 34000)  0.2380
#                36000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (28000, 28000)  0.2342
#                                                                                             (28000, 28000)  0.2344
#                42000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 21500)  0.2768
#                                                                                             (22000, 22000)  0.2764
#                48000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 16000)  0.2216
#                                                                                             (16000, 16000)  0.2212
#                54000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (10000, 10000)  0.2718
#                                                                                             (10000, 10000)  0.2720
#                60000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (3500, 3500)    0.2302
#                                                                                             (4000, 4000)    0.2302
#
# datasets                                                                                                            \
# score
# alpha                                                                                                         0.50
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (40000, 38500)  0.1058
#                                                                                             (64000, 64000)  0.1058
#                6000             cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (56500, 33000)  0.1168
#                                                                                             (58000, 58000)  0.1164
#                12000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (35000, 40500)  0.1244
#                                                                                             (52000, 52000)  0.1244
#                18000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34500, 44500)  0.1810
#                                                                                             (46000, 46000)  0.1806
#                24000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (32500, 36500)  0.2030
#                                                                                             (40000, 40000)  0.2026
#                30000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34000, 34000)  0.2514
#                                                                                             (34000, 34000)  0.2516
#                36000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (28000, 28000)  0.2632
#                                                                                             (28000, 28000)  0.2630
#                42000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 21500)  0.2794
#                                                                                             (22000, 22000)  0.2796
#                48000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 16000)  0.2574
#                                                                                             (16000, 16000)  0.2566
#                54000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (10000, 10000)  0.2698
#                                                                                             (10000, 10000)  0.2700
#                60000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (3500, 3500)    0.2130
#                                                                                             (4000, 4000)    0.2126
#
# datasets                                                                                                            \
# score
# alpha                                                                                                         0.75
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (40000, 38500)  0.1602
#                                                                                             (64000, 64000)  0.1600
#                6000             cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (56500, 33000)  0.1138
#                                                                                             (58000, 58000)  0.1136
#                12000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (35000, 40500)  0.1280
#                                                                                             (52000, 52000)  0.1282
#                18000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34500, 44500)  0.1910
#                                                                                             (46000, 46000)  0.1912
#                24000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (32500, 36500)  0.2076
#                                                                                             (40000, 40000)  0.2084
#                30000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34000, 34000)  0.2604
#                                                                                             (34000, 34000)  0.2598
#                36000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (28000, 28000)  0.2580
#                                                                                             (28000, 28000)  0.2582
#                42000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 21500)  0.2800
#                                                                                             (22000, 22000)  0.2798
#                48000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 16000)  0.2682
#                                                                                             (16000, 16000)  0.2684
#                54000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (10000, 10000)  0.2750
#                                                                                             (10000, 10000)  0.2750
#                60000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (3500, 3500)    0.1998
#                                                                                             (4000, 4000)    0.2000
#
# datasets                                                                                                            \
# score
# alpha                                                                                                         1.00
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (40000, 38500)  0.2214
#                                                                                             (64000, 64000)  0.2210
#                6000             cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (56500, 33000)  0.1130
#                                                                                             (58000, 58000)  0.1130
#                12000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (35000, 40500)  0.1376
#                                                                                             (52000, 52000)  0.1374
#                18000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34500, 44500)  0.2128
#                                                                                             (46000, 46000)  0.2126
#                24000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (32500, 36500)  0.2106
#                                                                                             (40000, 40000)  0.2108
#                30000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34000, 34000)  0.2416
#                                                                                             (34000, 34000)  0.2408
#                36000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (28000, 28000)  0.2222
#                                                                                             (28000, 28000)  0.2218
#                42000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 21500)  0.2540
#                                                                                             (22000, 22000)  0.2538
#                48000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 16000)  0.2602
#                                                                                             (16000, 16000)  0.2602
#                54000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (10000, 10000)  0.2780
#                                                                                             (10000, 10000)  0.2782
#                60000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (3500, 3500)    0.1874
#                                                                                             (4000, 4000)    0.1878
#
# datasets                                                                                                                \
# score                                                                                                      instability
# alpha                                                                                                              NaN
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (40000, 38500)     -0.0615
#                                                                                             (64000, 64000)     -0.0613
#                6000             cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (56500, 33000)     -0.0011
#                                                                                             (58000, 58000)     -0.0011
#                12000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (35000, 40500)     -0.0088
#                                                                                             (52000, 52000)     -0.0086
#                18000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34500, 44500)     -0.0182
#                                                                                             (46000, 46000)     -0.0180
#                24000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (32500, 36500)     -0.0039
#                                                                                             (40000, 40000)     -0.0043
#                30000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34000, 34000)     -0.0094
#                                                                                             (34000, 34000)     -0.0090
#                36000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (28000, 28000)     -0.0129
#                                                                                             (28000, 28000)     -0.0124
#                42000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 21500)     -0.0041
#                                                                                             (22000, 22000)     -0.0041
#                48000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 16000)     -0.0389
#                                                                                             (16000, 16000)     -0.0393
#                54000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (10000, 10000)     -0.0081
#                                                                                             (10000, 10000)     -0.0078
#                60000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (3500, 3500)       -0.0252
#                                                                                             (4000, 4000)       -0.0249
#
# datasets                                                                                                                  train  \
# score                                                                                                      interpolation_scores
# alpha                                                                                                                      0.00
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (40000, 38500)              0.09502
#                                                                                             (64000, 64000)              0.09564
#                6000             cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (56500, 33000)              0.16410
#                                                                                             (58000, 58000)              0.16534
#                12000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (35000, 40500)              0.16292
#                                                                                             (52000, 52000)              0.16056
#                18000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34500, 44500)              0.23180
#                                                                                             (46000, 46000)              0.23230
#                24000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (32500, 36500)              0.23140
#                                                                                             (40000, 40000)              0.23218
#                30000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34000, 34000)              0.19490
#                                                                                             (34000, 34000)              0.19498
#                36000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (28000, 28000)              0.24526
#                                                                                             (28000, 28000)              0.24698
#                42000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 21500)              0.22956
#                                                                                             (22000, 22000)              0.22906
#                48000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 16000)              0.22668
#                                                                                             (16000, 16000)              0.22588
#                54000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (10000, 10000)              0.24208
#                                                                                             (10000, 10000)              0.23828
#                60000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (3500, 3500)                0.25532
#                                                                                             (4000, 4000)                0.25404
#
# datasets                                                                                                             \
# score
# alpha                                                                                                          0.25
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (40000, 38500)  0.12134
#                                                                                             (64000, 64000)  0.12078
#                6000             cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (56500, 33000)  0.16806
#                                                                                             (58000, 58000)  0.16894
#                12000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (35000, 40500)  0.16328
#                                                                                             (52000, 52000)  0.16068
#                18000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34500, 44500)  0.23790
#                                                                                             (46000, 46000)  0.23898
#                24000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (32500, 36500)  0.24660
#                                                                                             (40000, 40000)  0.24536
#                30000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34000, 34000)  0.21368
#                                                                                             (34000, 34000)  0.21172
#                36000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (28000, 28000)  0.26598
#                                                                                             (28000, 28000)  0.26678
#                42000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 21500)  0.25662
#                                                                                             (22000, 22000)  0.25724
#                48000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 16000)  0.26450
#                                                                                             (16000, 16000)  0.26442
#                54000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (10000, 10000)  0.26316
#                                                                                             (10000, 10000)  0.26130
#                60000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (3500, 3500)    0.25328
#                                                                                             (4000, 4000)    0.25200
#
# datasets                                                                                                             \
# score
# alpha                                                                                                          0.50
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (40000, 38500)  0.10438
#                                                                                             (64000, 64000)  0.10560
#                6000             cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (56500, 33000)  0.16140
#                                                                                             (58000, 58000)  0.16410
#                12000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (35000, 40500)  0.16744
#                                                                                             (52000, 52000)  0.16834
#                18000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34500, 44500)  0.24798
#                                                                                             (46000, 46000)  0.24764
#                24000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (32500, 36500)  0.25114
#                                                                                             (40000, 40000)  0.25392
#                30000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34000, 34000)  0.22118
#                                                                                             (34000, 34000)  0.22404
#                36000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (28000, 28000)  0.26434
#                                                                                             (28000, 28000)  0.26192
#                42000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 21500)  0.26136
#                                                                                             (22000, 22000)  0.25802
#                48000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 16000)  0.28006
#                                                                                             (16000, 16000)  0.27726
#                54000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (10000, 10000)  0.26180
#                                                                                             (10000, 10000)  0.25940
#                60000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (3500, 3500)    0.24586
#                                                                                             (4000, 4000)    0.24550
#
# datasets                                                                                                             \
# score
# alpha                                                                                                          0.75
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (40000, 38500)  0.14010
#                                                                                             (64000, 64000)  0.13982
#                6000             cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (56500, 33000)  0.15492
#                                                                                             (58000, 58000)  0.15402
#                12000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (35000, 40500)  0.17702
#                                                                                             (52000, 52000)  0.17814
#                18000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34500, 44500)  0.25688
#                                                                                             (46000, 46000)  0.25800
#                24000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (32500, 36500)  0.25356
#                                                                                             (40000, 40000)  0.25400
#                30000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34000, 34000)  0.22224
#                                                                                             (34000, 34000)  0.22454
#                36000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (28000, 28000)  0.22432
#                                                                                             (28000, 28000)  0.22928
#                42000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 21500)  0.23804
#                                                                                             (22000, 22000)  0.23724
#                48000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 16000)  0.26350
#                                                                                             (16000, 16000)  0.26356
#                54000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (10000, 10000)  0.24962
#                                                                                             (10000, 10000)  0.25078
#                60000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (3500, 3500)    0.23794
#                                                                                             (4000, 4000)    0.23568
#
# datasets                                                                                                             \
# score
# alpha                                                                                                          1.00
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (40000, 38500)  0.20902
#                                                                                             (64000, 64000)  0.20764
#                6000             cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (56500, 33000)  0.14628
#                                                                                             (58000, 58000)  0.14396
#                12000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (35000, 40500)  0.18898
#                                                                                             (52000, 52000)  0.18842
#                18000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34500, 44500)  0.26048
#                                                                                             (46000, 46000)  0.26002
#                24000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (32500, 36500)  0.25094
#                                                                                             (40000, 40000)  0.25210
#                30000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34000, 34000)  0.20524
#                                                                                             (34000, 34000)  0.20970
#                36000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (28000, 28000)  0.16980
#                                                                                             (28000, 28000)  0.16750
#                42000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 21500)  0.19498
#                                                                                             (22000, 22000)  0.19384
#                48000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 16000)  0.21336
#                                                                                             (16000, 16000)  0.21520
#                54000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (10000, 10000)  0.23410
#                                                                                             (10000, 10000)  0.23398
#                60000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (3500, 3500)    0.22552
#                                                                                             (4000, 4000)    0.22724
#
# datasets
# score                                                                                                      instability
# alpha                                                                                                              NaN
# default_params init_model_idx_k job                                                seeds    model_idxes
# default_params 0                cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (40000, 38500)    -0.05700
#                                                                                             (64000, 64000)    -0.05600
#                6000             cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (56500, 33000)    -0.00891
#                                                                                             (58000, 58000)    -0.01069
#                12000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (35000, 40500)    -0.01303
#                                                                                             (52000, 52000)    -0.01393
#                18000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34500, 44500)    -0.01434
#                                                                                             (46000, 46000)    -0.01386
#                24000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (32500, 36500)    -0.00977
#                                                                                             (40000, 40000)    -0.00996
#                30000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (34000, 34000)    -0.00517
#                                                                                             (34000, 34000)    -0.00736
#                36000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (28000, 28000)    -0.03773
#                                                                                             (28000, 28000)    -0.03974
#                42000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 21500)    -0.01729
#                                                                                             (22000, 22000)    -0.01761
#                48000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (15000, 16000)    -0.00666
#                                                                                             (16000, 16000)    -0.00534
#                54000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (10000, 10000)    -0.00399
#                                                                                             (10000, 10000)    -0.00215
#                60000            cifar10-13.6.0-resnet-B-finetune-disableT--n_st... (21, 22) (3500, 3500)      -0.01490
#                                                                                             (4000, 4000)      -0.01340
