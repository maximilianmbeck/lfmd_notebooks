# %%
# %load_ext autoreload
# %autoreload 2
import torch
import numpy as np
import pandas as pd
from omegaconf import OmegaConf
from pathlib import Path
from pprint import pprint
# plotting
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# mycode
from repo import REPO
from ml_utilities.output_loader.result_loader import SweepResult, JobResult
from ml_utilities.output_loader import create_job_output_loader
from ml_utilities.output_loader.plot import plot_sweep_summary, plot_data_log_values
from tflearning.mode_connectivity.instability_analysis import InstabilityAnalyzer
from tflearning.mode_connectivity.plot import plot_barriers, plot_instability, plot_distances
from tflearning.learning_dynamics.covariance_analysis import GradCovarianceAnalyzer
from tflearning.learning_dynamics.plot import plot_covariance_statistics

# %% [markdown]
# # 15.11 Resnet MNIST Linear mode connectivity
#
# Reference: Frankle, Jonathan, Gintare Karolina Dziugaite, Daniel M. Roy, and Michael Carbin. 2020. “Linear Mode Connectivity and the Lottery Ticket Hypothesis.” arXiv. http://arxiv.org/abs/1912.05671.
#
#
# **RERUN 15**: In Experiment 15.2 we saw that the lenet network architecture is instable early on in training when used with CIFAR10. Now we want to confirm, that it is not architecture, but data dependent by using a resnet architecture for MNIST.
# We expect that in this case there should also be no barrier present.
#
# Starting point of other investigation:
# On MNIST the Lenet architecture is stable already at initialization.
# With this experiment we want to investigate whether this is due to the simple dataset (MNIST) or due to the small architecture. Therefore we rerun the same experiment on CIFAR10 with a larger input layer.

# %% [markdown]
# ## BN update OFF

# %%
spec = 'mnist-resnet-bnUpdateOff'
path = '/system/user/beck/pwbeck/projects/regularization/tflearning/outputs/IA-B-mnist-15.11.0-resnet--230124_164715'
insta = InstabilityAnalyzer.reload(sweep_result_dir=path, instability_folder_suffix='')
# Out:
# Collecting failed jobs: 100%|██████████| 10/10 [00:00<00:00, 56.20it/s]

# %%
# load training jobs
sweepr = insta.instability_sweep
mainjob = insta.main_training_job

# %%
mainjob.all_log_columns
# Out:
# {'val': ['log_step', 'loss', 'Accuracy', 'epoch', 'train_step'],
#  'train_step': ['log_step',
#   'loss',
#   'lr',
#   'Accuracy',
#   'weight_norm',
#   'grad_norm',
#   'epoch',
#   'train_step'],
#  'train': ['log_step', 'loss', 'lr', 'Accuracy', 'epoch', 'train_step'],
#  'timer': ['log_step',
#   'T_val_epoch',
#   'epoch',
#   'train_step',
#   'T_train_step',
#   'T_train_epoch']}

# %%
mainjob.get_summary(log_source='val', col_sel='Accuracy')
# Out:
#                                           best_train_step  best_val_score  \
# IA-A-mnist-15.11.0-resnet--230124_163846            10000        0.993667
#
#                                           Accuracy-train_step-10000  seed
# IA-A-mnist-15.11.0-resnet--230124_163846                   0.993667     0

# %%
mj_dl = mainjob.get_data_log(['train_step', 'val'])
f = plot_data_log_values(mj_dl, y_axis_left=['train_step-loss'], y_axis_right=['train_step-Accuracy', 'val-Accuracy'], xlim=(0, 1000), x_axis='train_step', title=f'Training_curves-{spec}', savefig=True)

# %%
sweepr.get_summary()
# Out:
# Collecting summaries: 100%|██████████| 10/10 [00:00<00:00, 6976.55it/s]
#                                                     best_train_step  \
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-0-see...            13500
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-100-s...             9000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000-...            18500
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000...            15000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000...            24000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000-...             9000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-250-s...             4500
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-50-se...            16500
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-500-s...            21000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000-...             5500
#
#                                                     best_val_score  \
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-0-see...        0.993333
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-100-s...        0.993833
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000-...        0.993833
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000...        0.993833
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000...        0.993333
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000-...        0.994000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-250-s...        0.993333
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-50-se...        0.993167
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-500-s...        0.993667
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000-...        0.993500
#
#                                                     trainer.resume_training.checkpoint_idx  \
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-0-see...                                       0
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-100-s...                                     100
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000-...                                    1000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000...                                   10000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000...                                   15000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000-...                                    2000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-250-s...                                     250
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-50-se...                                      50
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-500-s...                                     500
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000-...                                    5000
#
#                                                     seed
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-0-see...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-100-s...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000-...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000-...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-250-s...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-50-se...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-500-s...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000-...     1

# %%
df = insta.combined_results_dfs['datasets'].loc['default_params']
df
# Out:
# datasets                                                                                                val  \
# score                                                                                  interpolation_scores
# alpha                                                                                                  -0.1
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)             0.007694
#                                                                         (24001, 24001)             0.007860
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)             0.007195
#                                                                         (24000, 24001)             0.007029
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)              0.006839
#                                                                         (24000, 24001)             0.006506
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)              0.008002
#                                                                         (24000, 24001)             0.007836
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)             0.006839
#                                                                         (24000, 24001)             0.007171
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)             0.006673
#                                                                         (24000, 24001)             0.007005
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)              0.005675
#                                                                         (24000, 24001)             0.006839
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)              0.006839
#                                                                         (24000, 24001)             0.006839
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)             0.006340
#                                                                         (24000, 24001)             0.006839
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)             0.007005
#                                                                         (24000, 24001)             0.006673
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.0
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)  0.007171
#                                                                         (24001, 24001)  0.007171
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)  0.007528
#                                                                         (24000, 24001)  0.007528
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)   0.006174
#                                                                         (24000, 24001)  0.006506
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)   0.007504
#                                                                         (24000, 24001)  0.007504
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)  0.006839
#                                                                         (24000, 24001)  0.006839
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)  0.006506
#                                                                         (24000, 24001)  0.006506
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)   0.006008
#                                                                         (24000, 24001)  0.006673
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)   0.006839
#                                                                         (24000, 24001)  0.006839
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)  0.006174
#                                                                         (24000, 24001)  0.006839
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)  0.006673
#                                                                         (24000, 24001)  0.006673
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.1
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)  0.008169
#                                                                         (24001, 24001)  0.008169
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)  0.008026
#                                                                         (24000, 24001)  0.008192
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)   0.006340
#                                                                         (24000, 24001)  0.006673
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)   0.007005
#                                                                         (24000, 24001)  0.007005
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)  0.006839
#                                                                         (24000, 24001)  0.006839
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)  0.006174
#                                                                         (24000, 24001)  0.006340
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)   0.005842
#                                                                         (24000, 24001)  0.006174
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)   0.006839
#                                                                         (24000, 24001)  0.007005
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)  0.006174
#                                                                         (24000, 24001)  0.006839
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)  0.006673
#                                                                         (24000, 24001)  0.006839
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.3
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)  0.019187
#                                                                         (24001, 24001)  0.020018
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)  0.007171
#                                                                         (24000, 24001)  0.007171
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)   0.006506
#                                                                         (24000, 24001)  0.006839
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)   0.006174
#                                                                         (24000, 24001)  0.006008
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)  0.006340
#                                                                         (24000, 24001)  0.006340
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)  0.006340
#                                                                         (24000, 24001)  0.006839
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)   0.005675
#                                                                         (24000, 24001)  0.006008
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)   0.006839
#                                                                         (24000, 24001)  0.006839
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)  0.006506
#                                                                         (24000, 24001)  0.006839
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)  0.006863
#                                                                         (24000, 24001)  0.006673
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.5
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)  0.028021
#                                                                         (24001, 24001)  0.029706
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)  0.007361
#                                                                         (24000, 24001)  0.007338
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)   0.006673
#                                                                         (24000, 24001)  0.006839
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)   0.006008
#                                                                         (24000, 24001)  0.006174
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)  0.006506
#                                                                         (24000, 24001)  0.006340
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)  0.006673
#                                                                         (24000, 24001)  0.006839
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)   0.005675
#                                                                         (24000, 24001)  0.005842
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)   0.006863
#                                                                         (24000, 24001)  0.006673
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)  0.006696
#                                                                         (24000, 24001)  0.006839
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)  0.006696
#                                                                         (24000, 24001)  0.006673
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.7
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)  0.015530
#                                                                         (24001, 24001)  0.016361
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)  0.007195
#                                                                         (24000, 24001)  0.007338
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)   0.007005
#                                                                         (24000, 24001)  0.006839
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)   0.006174
#                                                                         (24000, 24001)  0.007005
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)  0.006340
#                                                                         (24000, 24001)  0.006340
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)  0.006673
#                                                                         (24000, 24001)  0.007005
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)   0.006506
#                                                                         (24000, 24001)  0.006174
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)   0.007029
#                                                                         (24000, 24001)  0.006340
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)  0.006696
#                                                                         (24000, 24001)  0.006673
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)  0.006696
#                                                                         (24000, 24001)  0.006673
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.9
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)  0.008026
#                                                                         (24001, 24001)  0.007836
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)  0.006530
#                                                                         (24000, 24001)  0.006506
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)   0.006174
#                                                                         (24000, 24001)  0.006673
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)   0.006198
#                                                                         (24000, 24001)  0.006839
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)  0.006696
#                                                                         (24000, 24001)  0.006673
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)  0.006863
#                                                                         (24000, 24001)  0.006673
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)   0.006863
#                                                                         (24000, 24001)  0.006673
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)   0.006530
#                                                                         (24000, 24001)  0.006839
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)  0.006530
#                                                                         (24000, 24001)  0.006673
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)  0.006530
#                                                                         (24000, 24001)  0.006839
#
# datasets                                                                                          \
# score
# alpha                                                                                        1.0
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)  0.006364
#                                                                         (24001, 24001)  0.006839
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)  0.006364
#                                                                         (24000, 24001)  0.006839
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)   0.006364
#                                                                         (24000, 24001)  0.006839
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)   0.006364
#                                                                         (24000, 24001)  0.006839
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)  0.006364
#                                                                         (24000, 24001)  0.006839
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)  0.006364
#                                                                         (24000, 24001)  0.006839
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)   0.006364
#                                                                         (24000, 24001)  0.006839
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)   0.006364
#                                                                         (24000, 24001)  0.006839
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)  0.006364
#                                                                         (24000, 24001)  0.006839
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)  0.006364
#                                                                         (24000, 24001)  0.006839
#
# datasets                                                                                          \
# score
# alpha                                                                                        1.1
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)  0.007860
#                                                                         (24001, 24001)  0.008359
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)  0.007029
#                                                                         (24000, 24001)  0.007171
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)   0.006863
#                                                                         (24000, 24001)  0.007195
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)   0.006530
#                                                                         (24000, 24001)  0.007171
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)  0.006530
#                                                                         (24000, 24001)  0.007504
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)  0.006364
#                                                                         (24000, 24001)  0.007195
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)   0.006530
#                                                                         (24000, 24001)  0.006839
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)   0.006530
#                                                                         (24000, 24001)  0.006673
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)  0.006364
#                                                                         (24000, 24001)  0.006839
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)  0.006364
#                                                                         (24000, 24001)  0.006839
#
# datasets                                                                                            \
# score                                                                                  instability
# alpha                                                                                          NaN
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)    0.021253
#                                                                         (24001, 24001)    0.022701
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)    0.001080
#                                                                         (24000, 24001)    0.001009
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)     0.000736
#                                                                         (24000, 24001)    0.000166
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)     0.000570
#                                                                         (24000, 24001)    0.000332
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)    0.000237
#                                                                         (24000, 24001)    0.000000
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)    0.000427
#                                                                         (24000, 24001)    0.000332
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)     0.000677
#                                                                         (24000, 24001)    0.000083
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)     0.000427
#                                                                         (24000, 24001)    0.000166
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)    0.000427
#                                                                         (24000, 24001)    0.000000
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)    0.000344
#                                                                         (24000, 24001)    0.000083
#
# datasets                                                                                              train  \
# score                                                                                  interpolation_scores
# alpha                                                                                                  -0.1
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)                  0.0
#                                                                         (24001, 24001)                  0.0
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)                  0.0
#                                                                         (24000, 24001)                  0.0
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)                   0.0
#                                                                         (24000, 24001)                  0.0
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)                   0.0
#                                                                         (24000, 24001)                  0.0
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)                  0.0
#                                                                         (24000, 24001)                  0.0
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)                  0.0
#                                                                         (24000, 24001)                  0.0
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)                   0.0
#                                                                         (24000, 24001)                  0.0
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)                   0.0
#                                                                         (24000, 24001)                  0.0
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)                  0.0
#                                                                         (24000, 24001)                  0.0
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)                  0.0
#                                                                         (24000, 24001)                  0.0
#
# datasets                                                                                     \
# score
# alpha                                                                                   0.0
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)  0.0
#                                                                         (24001, 24001)  0.0
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)  0.0
#                                                                         (24000, 24001)  0.0
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)   0.0
#                                                                         (24000, 24001)  0.0
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)   0.0
#                                                                         (24000, 24001)  0.0
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)  0.0
#                                                                         (24000, 24001)  0.0
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)  0.0
#                                                                         (24000, 24001)  0.0
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)   0.0
#                                                                         (24000, 24001)  0.0
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)   0.0
#                                                                         (24000, 24001)  0.0
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)  0.0
#                                                                         (24000, 24001)  0.0
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)  0.0
#                                                                         (24000, 24001)  0.0
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.1
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)  0.000037
#                                                                         (24001, 24001)  0.000056
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.3
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)  0.010626
#                                                                         (24001, 24001)  0.011219
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)  0.000019
#                                                                         (24000, 24001)  0.000000
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.5
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)  0.018148
#                                                                         (24001, 24001)  0.018516
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)  0.000056
#                                                                         (24000, 24001)  0.000037
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)   0.000037
#                                                                         (24000, 24001)  0.000000
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)   0.000019
#                                                                         (24000, 24001)  0.000019
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.7
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)  0.007276
#                                                                         (24001, 24001)  0.007535
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)  0.000019
#                                                                         (24000, 24001)  0.000000
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)   0.000019
#                                                                         (24000, 24001)  0.000000
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.9
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)  0.000074
#                                                                         (24001, 24001)  0.000037
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
#
# datasets                                                                                     \
# score
# alpha                                                                                   1.0
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)  0.0
#                                                                         (24001, 24001)  0.0
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)  0.0
#                                                                         (24000, 24001)  0.0
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)   0.0
#                                                                         (24000, 24001)  0.0
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)   0.0
#                                                                         (24000, 24001)  0.0
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)  0.0
#                                                                         (24000, 24001)  0.0
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)  0.0
#                                                                         (24000, 24001)  0.0
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)   0.0
#                                                                         (24000, 24001)  0.0
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)   0.0
#                                                                         (24000, 24001)  0.0
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)  0.0
#                                                                         (24000, 24001)  0.0
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)  0.0
#                                                                         (24000, 24001)  0.0
#
# datasets                                                                                          \
# score
# alpha                                                                                        1.1
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)  0.000019
#                                                                         (24001, 24001)  0.000000
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)   0.000000
#                                                                         (24000, 24001)  0.000000
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)  0.000000
#                                                                         (24000, 24001)  0.000000
#
# datasets
# score                                                                                  instability
# alpha                                                                                          NaN
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)    0.018148
#                                                                         (24001, 24001)    0.018516
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)    0.000056
#                                                                         (24000, 24001)    0.000037
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)     0.000037
#                                                                         (24000, 24001)    0.000000
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)     0.000019
#                                                                         (24000, 24001)    0.000019
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)    0.000000
#                                                                         (24000, 24001)    0.000000
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)    0.000000
#                                                                         (24000, 24001)    0.000000
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)     0.000000
#                                                                         (24000, 24001)    0.000000
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)     0.000000
#                                                                         (24000, 24001)    0.000000
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)    0.000000
#                                                                         (24000, 24001)    0.000000
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)    0.000000
#                                                                         (24000, 24001)    0.000000

# %%
f = plot_barriers(instability_df=insta.combined_results_dfs['datasets'].loc['default_params'], title=f'Barriers {spec}', save_format='png')

# %%
f = plot_instability(instability_df=insta.combined_results_dfs['datasets'].loc['default_params'], title=f'Instability {spec}', x_scale='symlog', save_format='png')

# %%
df = insta.combined_results_dfs['distances'].loc['default_params']
df
# Out:
# distances                                                                              l2distance  \
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)   6.948958
#                                                                         (24001, 24001)   6.982873
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)   3.990982
#                                                                         (24000, 24001)   4.014075
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)    3.537391
#                                                                         (24000, 24001)   3.608372
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)    3.182853
#                                                                         (24000, 24001)   3.198940
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)   2.748499
#                                                                         (24000, 24001)   2.762471
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)   2.281593
#                                                                         (24000, 24001)   2.291177
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)    1.767471
#                                                                         (24000, 24001)   1.778059
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)    0.993289
#                                                                         (24000, 24001)   0.955286
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)   0.337505
#                                                                         (24000, 24001)   0.280313
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)   0.296724
#                                                                         (24000, 24001)   0.027482
#
# distances                                                                              cosinesimilarity
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (13500, 10000)         0.987717
#                                                                         (24001, 24001)         0.987604
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (16500, 10000)         0.995944
#                                                                         (24000, 24001)         0.995899
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (9000, 10000)          0.996811
#                                                                         (24000, 24001)         0.996687
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (4500, 10000)          0.997422
#                                                                         (24000, 24001)         0.997397
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (21000, 10000)         0.998077
#                                                                         (24000, 24001)         0.998058
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (18500, 10000)         0.998674
#                                                                         (24000, 24001)         0.998664
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (9000, 10000)          0.999204
#                                                                         (24000, 24001)         0.999196
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (5500, 10000)          0.999749
#                                                                         (24000, 24001)         0.999768
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (15000, 10000)         0.999971
#                                                                         (24000, 24001)         0.999980
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 10000)         0.999978
#                                                                         (24000, 24001)         1.000000

# %%
f = plot_distances(distances_df=insta.combined_results_dfs['distances'].loc['default_params'], title=f'Distances {spec}', save_format='png')

# %% [markdown]
# ## BNupdate ON

# %%
spec = 'mnist-resnet-bnUpdateOn'
path = '/system/user/beck/pwbeck/projects/regularization/tflearning/outputs/IA-B-mnist-15.11.0-resnet--230124_164715'
insta = InstabilityAnalyzer.reload(sweep_result_dir=path, instability_folder_suffix='update_bn')
# Out:
# Collecting failed jobs: 100%|██████████| 10/10 [00:00<00:00, 51.83it/s]

# %%
# load training jobs
sweepr = insta.instability_sweep
mainjob = insta.main_training_job

# %%
# mainjob.all_log_columns

# %%
mainjob.get_summary(log_source='val', col_sel='Accuracy')
# Out:
#                                           best_train_step  best_val_score  \
# IA-A-mnist-15.11.0-resnet--230124_163846            10000        0.993667
#
#                                           Accuracy-train_step-10000  seed
# IA-A-mnist-15.11.0-resnet--230124_163846                   0.993667     0

# %%
sweepr.get_summary()
# Out:
# Collecting summaries: 100%|██████████| 10/10 [00:00<00:00, 4580.43it/s]
#                                                     best_train_step  \
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-0-see...            13500
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-100-s...             9000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000-...            18500
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000...            15000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000...            24000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000-...             9000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-250-s...             4500
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-50-se...            16500
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-500-s...            21000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000-...             5500
#
#                                                     best_val_score  \
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-0-see...        0.993333
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-100-s...        0.993833
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000-...        0.993833
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000...        0.993833
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000...        0.993333
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000-...        0.994000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-250-s...        0.993333
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-50-se...        0.993167
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-500-s...        0.993667
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000-...        0.993500
#
#                                                     trainer.resume_training.checkpoint_idx  \
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-0-see...                                       0
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-100-s...                                     100
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000-...                                    1000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000...                                   10000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000...                                   15000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000-...                                    2000
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-250-s...                                     250
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-50-se...                                      50
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-500-s...                                     500
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000-...                                    5000
#
#                                                     seed
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-0-see...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-100-s...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000-...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000-...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-250-s...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-50-se...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-500-s...     1
# IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000-...     1

# %%
# mj_dl = mainjob.get_data_log(['train_step', 'val'])
# f = plot_data_log_values(mj_dl, y_axis_left=['train_step-loss'], y_axis_right=['train_step-Accuracy', 'val-Accuracy'], xlim=(0, 10000), x_axis='train_step', title=f'Training_curves-{spec}', savefig=True)

# %%
df = insta.combined_results_dfs['datasets'].loc['default_params']
df
# Out:
# datasets                                                                                                val  \
# score                                                                                  interpolation_scores
# alpha                                                                                                  -0.1
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)             0.007504
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)             0.007195
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)             0.006506
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)             0.007670
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)             0.007338
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)             0.007171
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)             0.006673
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)             0.006530
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)             0.006340
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)             0.007171
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.0
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)  0.007670
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)  0.007029
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)  0.006673
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)  0.007171
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)  0.007171
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)  0.006506
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)  0.006506
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)  0.006696
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)  0.006340
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)  0.007171
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.1
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)  0.007338
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)  0.007361
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)  0.006839
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)  0.007005
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)  0.006839
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)  0.006839
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)  0.006506
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)  0.006696
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)  0.006340
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)  0.007171
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.3
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)  0.008169
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)  0.007694
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)  0.006506
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)  0.006174
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)  0.006506
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)  0.007005
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)  0.006506
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)  0.007029
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)  0.007005
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)  0.007171
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.5
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)  0.009166
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)  0.007528
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)  0.007005
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)  0.006506
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)  0.006673
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)  0.006839
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)  0.006340
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)  0.006673
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)  0.007005
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)  0.007338
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.7
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)  0.009332
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)  0.006506
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)  0.006340
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)  0.006839
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)  0.006673
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)  0.007005
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)  0.006340
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)  0.006673
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)  0.007005
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)  0.007338
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.9
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)  0.006839
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)  0.006673
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)  0.006673
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)  0.007171
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)  0.006673
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)  0.007005
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)  0.006839
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)  0.007171
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)  0.007171
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)  0.007338
#
# datasets                                                                                          \
# score
# alpha                                                                                        1.0
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)  0.007171
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)  0.007171
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)  0.007171
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)  0.007171
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)  0.007171
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)  0.007171
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)  0.007171
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)  0.007171
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)  0.007171
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)  0.007171
#
# datasets                                                                                          \
# score
# alpha                                                                                        1.1
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)  0.007860
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)  0.007171
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)  0.007528
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)  0.007504
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)  0.007694
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)  0.007361
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)  0.007338
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)  0.007338
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)  0.007504
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)  0.007338
#
# datasets                                                                                            \
# score                                                                                  instability
# alpha                                                                                          NaN
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)    0.001912
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)    0.000594
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)    0.000249
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)    0.000000
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)    0.000000
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)    0.000332
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)    0.000332
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)    0.000237
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)    0.000416
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)    0.000166
#
# datasets                                                                                              train  \
# score                                                                                  interpolation_scores
# alpha                                                                                                  -0.1
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)                  0.0
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)                  0.0
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)                  0.0
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)                  0.0
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)                  0.0
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)                  0.0
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)                  0.0
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)                  0.0
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)                  0.0
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)                  0.0
#
# datasets                                                                                     \
# score
# alpha                                                                                   0.0
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)  0.0
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)  0.0
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)  0.0
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)  0.0
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)  0.0
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)  0.0
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)  0.0
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)  0.0
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)  0.0
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)  0.0
#
# datasets                                                                                     \
# score
# alpha                                                                                   0.1
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)  0.0
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)  0.0
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)  0.0
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)  0.0
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)  0.0
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)  0.0
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)  0.0
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)  0.0
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)  0.0
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)  0.0
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.3
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)  0.001796
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)  0.000000
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)  0.000000
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)  0.000000
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)  0.000000
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)  0.000000
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)  0.000000
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)  0.000000
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)  0.000000
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)  0.000000
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.5
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)  0.004351
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)  0.000037
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)  0.000000
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)  0.000000
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)  0.000000
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)  0.000000
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)  0.000000
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)  0.000000
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)  0.000000
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)  0.000000
#
# datasets                                                                                          \
# score
# alpha                                                                                        0.7
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)  0.001629
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)  0.000000
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)  0.000000
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)  0.000000
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)  0.000000
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)  0.000000
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)  0.000000
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)  0.000000
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)  0.000000
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)  0.000000
#
# datasets                                                                                     \
# score
# alpha                                                                                   0.9
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)  0.0
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)  0.0
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)  0.0
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)  0.0
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)  0.0
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)  0.0
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)  0.0
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)  0.0
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)  0.0
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)  0.0
#
# datasets                                                                                     \
# score
# alpha                                                                                   1.0
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)  0.0
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)  0.0
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)  0.0
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)  0.0
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)  0.0
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)  0.0
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)  0.0
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)  0.0
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)  0.0
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)  0.0
#
# datasets                                                                                     \
# score
# alpha                                                                                   1.1
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)  0.0
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)  0.0
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)  0.0
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)  0.0
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)  0.0
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)  0.0
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)  0.0
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)  0.0
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)  0.0
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)  0.0
#
# datasets
# score                                                                                  instability
# alpha                                                                                          NaN
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)    0.004351
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)    0.000037
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)    0.000000
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)    0.000000
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)    0.000000
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)    0.000000
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)    0.000000
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)    0.000000
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)    0.000000
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)    0.000000

# %%
f = plot_barriers(instability_df=insta.combined_results_dfs['datasets'].loc['default_params'], title=f'Barriers {spec}', save_format='png')

# %%
f = plot_instability(instability_df=insta.combined_results_dfs['datasets'].loc['default_params'], title=f'Instability {spec}', x_scale='symlog', save_format='png')

# %%
grada = GradCovarianceAnalyzer(job=mainjob, checkpoint_idxs=[], num_batches=[25], batch_sizes=[128], device='cuda:0', save_folder_suffix='', save_to_disk=True)
stats, eigvals = grada.covariance_analysis()
# Out:
# The save folder already exists. Reloading those results. To recompute choose different save_folder_suffix.

# %%
scale = 'linear'
f = plot_covariance_statistics(stats, title=f'GradCovariance {spec} - {scale}', save_format='png', x_scale=scale)

# %%
scale = 'symlog'
f = plot_covariance_statistics(stats, title=f'GradCovariance {spec} - {scale}', save_format='png', x_scale=scale)

# %%
scale = 'symlog'
f = plot_covariance_statistics(stats, title=f'GradCov[me] {spec}--{scale}', save_format='png', x_scale=scale, statistic_names=['max_eigval'], figsize=(1 * 12 * 1 / 2.54, 1.5 * 8 * 1 / 2.54))

# %%
df = insta.combined_results_dfs['distances'].loc['default_params']
df
# Out:
# distances                                                                              l2distance  \
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)   6.982973
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)   4.014140
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)   3.608430
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)   3.199008
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)   2.762508
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)   2.291223
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)   1.778089
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)   0.955301
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)   0.280321
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)   0.027482
#
# distances                                                                              cosinesimilarity
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-mnist-15.11.0-resnet--checkpoint_idx-0     (1, 0) (24001, 24001)         0.987604
# 50               IA-B-mnist-15.11.0-resnet--checkpoint_idx-50    (1, 0) (24000, 24001)         0.995899
# 100              IA-B-mnist-15.11.0-resnet--checkpoint_idx-100   (1, 0) (24000, 24001)         0.996687
# 250              IA-B-mnist-15.11.0-resnet--checkpoint_idx-250   (1, 0) (24000, 24001)         0.997397
# 500              IA-B-mnist-15.11.0-resnet--checkpoint_idx-500   (1, 0) (24000, 24001)         0.998058
# 1000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-1000  (1, 0) (24000, 24001)         0.998664
# 2000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-2000  (1, 0) (24000, 24001)         0.999196
# 5000             IA-B-mnist-15.11.0-resnet--checkpoint_idx-5000  (1, 0) (24000, 24001)         0.999768
# 10000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-10000 (1, 0) (24000, 24001)         0.999980
# 15000            IA-B-mnist-15.11.0-resnet--checkpoint_idx-15000 (1, 0) (24000, 24001)         1.000000

# %%
f = plot_distances(distances_df=insta.combined_results_dfs['distances'].loc['default_params'], title=f'Distances {spec}', save_format='png')
