# %%
# %load_ext autoreload
# %autoreload 2
import torch
import numpy as np
import pandas as pd
from omegaconf import OmegaConf
from pathlib import Path
from pprint import pprint
import copy
# plotting
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# mycode
from repo import REPO
from ml_utilities.output_loader.result_loader import SweepResult, JobResult
from ml_utilities.output_loader import create_job_output_loader
from ml_utilities.output_loader.plot import plot_sweep_summary, plot_data_log_values

# %% [markdown]
# # 15 CIFAR10 Instability Analysis debug
#
# I use this notebook for debugging the resume training functionality of the trainer.

# %%
# this is the full config for the instability analysis
config_yaml = """
config:
  run_script_name: train_instability_analysis
  run_script_kwargs:
    run_config:
      exec_type: parallel
      hostname: dragonfly
      gpu_ids: [0, 1]
      runs_per_gpu: 3
      wandb:
        init:
          tags:
          - ${config.run_script_kwargs.job_config.experiment_data.experiment_tag}_exps
          - run_handler
          notes: null
          group: ${config.run_script_kwargs.job_config.experiment_data.experiment_tag}
          job_type: run_handler

    start_num: 0

    job_config:
      experiment_data:
        entity: jkuiml-fsl
        project_name: tflearning
        experiment_tag: '15.0'
        experiment_type: startnum_${config.run_script_kwargs.start_num}
        experiment_name: cifar10-${config.run_script_kwargs.job_config.experiment_data.experiment_tag}.${config.run_script_kwargs.start_num}-lenet #! override this in script, add prefix 'IA-X-'
        experiment_dir: null
        experiment_notes: 
        seed: 0
        gpu_id: 1
      wandb:
        init:
          tags:
          - ${config.run_script_kwargs.job_config.experiment_data.experiment_tag}_exps
          notes: ${config.run_script_kwargs.job_config.experiment_data.experiment_notes}
          group: ${config.run_script_kwargs.job_config.experiment_data.experiment_tag}
          job_type: ${config.run_script_kwargs.job_config.experiment_data.experiment_type}

      model:
        model_cfg: lenet_300_100_relu_cifar10 #resnet20-cifar10-B

      trainer:
        training_setup: supervised
        n_steps: 64e3
        log_train_step_every: 1
        log_additional_train_step_every_multiplier: 1
        log_additional_logs: true
        val_every: 500
        save_every: 10000 # CHECK
        batch_size: 128
        optimizer_scheduler:
          optimizer_name: AdamW
          optimizer_kwargs:
            lr: 0.001
            weight_decay: 0.0
          lr_scheduler_name: MultiStepLR
          lr_scheduler_kwargs:
            milestones: [32e3, 48e3]
            gamma: 0.1
        loss: crossentropy
        metrics:
        - Accuracy
        num_workers: 4

      data:
        dataset: cifar10
        dataset_kwargs:
          data_root_path: /system/user/beck/pwbeck/data
        dataset_split:
          train_val_split: 0.9
          # restrict_n_samples_train_task: 100
        train_split_transforms:
          image_transforms:
          - RandomHorizontalFlip
          - RandomCrop:
              size: 32
              padding: 4
          tensor_transforms: 
          joint_tensor_transforms: 
          enable_transforms: True

    instability_analysis_config: 
      score_fn: TError #TAccuracy
      interpolation_factors: [-0.1000,  0.0000,  0.1000,  0.3000,  0.5000,  0.7000,  0.9000,  1.0000, 1.1000]
      device: 1 #! override from config
      interpolate_linear_kwargs: 
        dataloader_kwargs: 
          batch_size: 128 #! override from config
      init_model_idxes_ks_or_every: [0,50,100,250,500,1000,2000,5000,10000,15000] # show instability at these checkpoint idxes
"""
cfg = OmegaConf.create(config_yaml)

# %%
cf10_lenet_instability_path = '/system/user/beck/pwbeck/projects/regularization/erank/outputs/IA-B-cifar10-15.1.0-lenet--230117_084806/instability_analysis/hp_result_dfs/default_params.p'

# %%
cf10_lenet_instability = pd.read_pickle(cf10_lenet_instability_path)
cf10_lenet_instability.keys()
# Out:
# dict_keys(['datasets', 'distances'])

# %%
res_df = cf10_lenet_instability['datasets']
res_df
# Out:
# datasets                                                                                                val  \
# score                                                                                  interpolation_scores
# alpha                                                                                                  0.00
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0     (1, 2) (64002, 64002)             0.453711
# 50               IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50    (1, 2) (64001, 64001)             0.453516
# 100              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100   (1, 2) (64001, 64001)             0.445312
# 250              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250   (1, 2) (64001, 64001)             0.449219
# 500              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500   (1, 2) (64001, 64001)             0.448047
# 1000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000  (1, 2) (64002, 64002)             0.452148
# 2000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000  (1, 2) (64001, 64001)             0.443359
# 5000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000  (1, 2) (64001, 64001)             0.448438
# 10000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000 (1, 2) (64001, 64001)             0.444922
# 15000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000 (1, 2) (64001, 64001)             0.443945
#
# datasets                                                                                          \
# score
# alpha                                                                                       0.25
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0     (1, 2) (64002, 64002)  0.564648
# 50               IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50    (1, 2) (64001, 64001)  0.509766
# 100              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100   (1, 2) (64001, 64001)  0.506641
# 250              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250   (1, 2) (64001, 64001)  0.479297
# 500              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500   (1, 2) (64001, 64001)  0.470117
# 1000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000  (1, 2) (64002, 64002)  0.461133
# 2000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000  (1, 2) (64001, 64001)  0.444922
# 5000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000  (1, 2) (64001, 64001)  0.447656
# 10000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000 (1, 2) (64001, 64001)  0.446680
# 15000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000 (1, 2) (64001, 64001)  0.448438
#
# datasets                                                                                          \
# score
# alpha                                                                                       0.50
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0     (1, 2) (64002, 64002)  0.641406
# 50               IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50    (1, 2) (64001, 64001)  0.555078
# 100              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100   (1, 2) (64001, 64001)  0.544141
# 250              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250   (1, 2) (64001, 64001)  0.498828
# 500              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500   (1, 2) (64001, 64001)  0.489258
# 1000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000  (1, 2) (64002, 64002)  0.484766
# 2000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000  (1, 2) (64001, 64001)  0.457422
# 5000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000  (1, 2) (64001, 64001)  0.453125
# 10000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000 (1, 2) (64001, 64001)  0.444531
# 15000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000 (1, 2) (64001, 64001)  0.452539
#
# datasets                                                                                          \
# score
# alpha                                                                                       0.75
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0     (1, 2) (64002, 64002)  0.561133
# 50               IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50    (1, 2) (64001, 64001)  0.513672
# 100              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100   (1, 2) (64001, 64001)  0.500586
# 250              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250   (1, 2) (64001, 64001)  0.477930
# 500              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500   (1, 2) (64001, 64001)  0.472852
# 1000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000  (1, 2) (64002, 64002)  0.475977
# 2000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000  (1, 2) (64001, 64001)  0.454688
# 5000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000  (1, 2) (64001, 64001)  0.448633
# 10000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000 (1, 2) (64001, 64001)  0.444727
# 15000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000 (1, 2) (64001, 64001)  0.451562
#
# datasets                                                                                          \
# score
# alpha                                                                                       1.00
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0     (1, 2) (64002, 64002)  0.459180
# 50               IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50    (1, 2) (64001, 64001)  0.454297
# 100              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100   (1, 2) (64001, 64001)  0.450781
# 250              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250   (1, 2) (64001, 64001)  0.455469
# 500              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500   (1, 2) (64001, 64001)  0.456250
# 1000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000  (1, 2) (64002, 64002)  0.455469
# 2000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000  (1, 2) (64001, 64001)  0.444336
# 5000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000  (1, 2) (64001, 64001)  0.451367
# 10000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000 (1, 2) (64001, 64001)  0.443164
# 15000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000 (1, 2) (64001, 64001)  0.447656
#
# datasets                                                                                            \
# score                                                                                  instability
# alpha                                                                                          NaN
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0     (1, 2) (64002, 64002)    0.184961
# 50               IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50    (1, 2) (64001, 64001)    0.101172
# 100              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100   (1, 2) (64001, 64001)    0.096094
# 250              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250   (1, 2) (64001, 64001)    0.046484
# 500              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500   (1, 2) (64001, 64001)    0.037109
# 1000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000  (1, 2) (64002, 64002)    0.030957
# 2000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000  (1, 2) (64001, 64001)    0.013574
# 5000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000  (1, 2) (64001, 64001)    0.003223
# 10000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000 (1, 2) (64001, 64001)    0.002637
# 15000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000 (1, 2) (64001, 64001)    0.006738
#
# datasets                                                                                              train  \
# score                                                                                  interpolation_scores
# alpha                                                                                                  0.00
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0     (1, 2) (64002, 64002)             0.373180
# 50               IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50    (1, 2) (64001, 64001)             0.369158
# 100              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100   (1, 2) (64001, 64001)             0.366734
# 250              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250   (1, 2) (64001, 64001)             0.367427
# 500              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500   (1, 2) (64001, 64001)             0.367686
# 1000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000  (1, 2) (64002, 64002)             0.366388
# 2000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000  (1, 2) (64001, 64001)             0.367220
# 5000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000  (1, 2) (64001, 64001)             0.362480
# 10000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000 (1, 2) (64001, 64001)             0.365464
# 15000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000 (1, 2) (64001, 64001)             0.365937
#
# datasets                                                                                          \
# score
# alpha                                                                                       0.25
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0     (1, 2) (64002, 64002)  0.509013
# 50               IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50    (1, 2) (64001, 64001)  0.452079
# 100              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100   (1, 2) (64001, 64001)  0.427956
# 250              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250   (1, 2) (64001, 64001)  0.416588
# 500              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500   (1, 2) (64001, 64001)  0.404701
# 1000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000  (1, 2) (64002, 64002)  0.392376
# 2000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000  (1, 2) (64001, 64001)  0.379027
# 5000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000  (1, 2) (64001, 64001)  0.369220
# 10000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000 (1, 2) (64001, 64001)  0.366731
# 15000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000 (1, 2) (64001, 64001)  0.365668
#
# datasets                                                                                          \
# score
# alpha                                                                                       0.50
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0     (1, 2) (64002, 64002)  0.650849
# 50               IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50    (1, 2) (64001, 64001)  0.515482
# 100              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100   (1, 2) (64001, 64001)  0.476964
# 250              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250   (1, 2) (64001, 64001)  0.460506
# 500              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500   (1, 2) (64001, 64001)  0.431170
# 1000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000  (1, 2) (64002, 64002)  0.410102
# 2000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000  (1, 2) (64001, 64001)  0.390581
# 5000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000  (1, 2) (64001, 64001)  0.376100
# 10000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000 (1, 2) (64001, 64001)  0.370544
# 15000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000 (1, 2) (64001, 64001)  0.366073
#
# datasets                                                                                          \
# score
# alpha                                                                                       0.75
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0     (1, 2) (64002, 64002)  0.496589
# 50               IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50    (1, 2) (64001, 64001)  0.452797
# 100              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100   (1, 2) (64001, 64001)  0.428906
# 250              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250   (1, 2) (64001, 64001)  0.419828
# 500              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500   (1, 2) (64001, 64001)  0.404497
# 1000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000  (1, 2) (64002, 64002)  0.389811
# 2000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000  (1, 2) (64001, 64001)  0.379878
# 5000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000  (1, 2) (64001, 64001)  0.369787
# 10000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000 (1, 2) (64001, 64001)  0.367291
# 15000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000 (1, 2) (64001, 64001)  0.366344
#
# datasets                                                                                          \
# score
# alpha                                                                                       1.00
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0     (1, 2) (64002, 64002)  0.364909
# 50               IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50    (1, 2) (64001, 64001)  0.370938
# 100              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100   (1, 2) (64001, 64001)  0.366924
# 250              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250   (1, 2) (64001, 64001)  0.364941
# 500              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500   (1, 2) (64001, 64001)  0.368329
# 1000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000  (1, 2) (64002, 64002)  0.363168
# 2000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000  (1, 2) (64001, 64001)  0.364608
# 5000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000  (1, 2) (64001, 64001)  0.365067
# 10000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000 (1, 2) (64001, 64001)  0.367728
# 15000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000 (1, 2) (64001, 64001)  0.366798
#
# datasets
# score                                                                                  instability
# alpha                                                                                          NaN
# init_model_idx_k job                                             seeds  model_idxes
# 0                IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0     (1, 2) (64002, 64002)    0.281805
# 50               IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50    (1, 2) (64001, 64001)    0.145434
# 100              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100   (1, 2) (64001, 64001)    0.110136
# 250              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250   (1, 2) (64001, 64001)    0.094322
# 500              IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500   (1, 2) (64001, 64001)    0.063162
# 1000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000  (1, 2) (64002, 64002)    0.045324
# 2000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000  (1, 2) (64001, 64001)    0.024667
# 5000             IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000  (1, 2) (64001, 64001)    0.012327
# 10000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000 (1, 2) (64001, 64001)    0.003948
# 15000            IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000 (1, 2) (64001, 64001)    0.000430

# %% [markdown]
# ## 15.0 Standard Training Run from which later two seeds will be started.

# %%
run_command = REPO.create_experiment(cfg, override=False)
print(run_command)
# Out:
# python run.py --config-name cifar10-14.0.8-resnet-B.yaml

# %%
sweepr = REPO.get_output_loader(cfg)
print(sweepr)
sweepr
# Out:
# /system/user/publicwork/beck/projects/regularization/erank/outputs/cifar10-14.0.8-resnet-B--230116_112841
# JobResult(/system/user/publicwork/beck/projects/regularization/erank/outputs/cifar10-14.0.8-resnet-B--230116_112841)

# %%
sweepr.available_model_checkpoint_indices
# Out:
# [0, 50, 100, 250, 500, 750, 2000, 2500, 10000]

# %%
swr = SweepResult('/system/user/beck/pwbeck/projects/regularization/erank/outputs/IA-B-cifar10-15.1.0-lenet--230117_084806')

# %%
swr.seeds
# Out:
# [1, 2]

# %%
df, js = swr.query_jobs({'seed': [1, 3]})
df
# Out:
#                                                     best_train_step  \
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0-see...            63500
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100-s...            41500
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000-...            45500
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000...            64000
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000...            64000
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000-...            64000
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250-s...            55500
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50-se...            56500
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500-s...            64000
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000-...            59500
#
#                                                     best_val_score  \
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0-see...          0.5512
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100-s...          0.5644
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000-...          0.5598
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000...          0.5596
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000...          0.5604
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000-...          0.5640
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250-s...          0.5550
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50-se...          0.5544
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500-s...          0.5562
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000-...          0.5636
#
#                                                     trainer.resume_training.checkpoint_idx  \
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0-see...                                       0
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100-s...                                     100
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000-...                                    1000
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000...                                   10000
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000...                                   15000
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000-...                                    2000
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250-s...                                     250
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50-se...                                      50
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500-s...                                     500
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000-...                                    5000
#
#                                                     seed
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0-see...     1
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100-s...     1
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000-...     1
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000...     1
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000...     1
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000-...     1
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250-s...     1
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50-se...     1
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500-s...     1
# IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000-...     1

# %%
js
# Out:
# [JobResult(/system/user/beck/pwbeck/projects/regularization/erank/outputs/IA-B-cifar10-15.1.0-lenet--230117_084806/outputs/IA-B-cifar10-15.1.0-lenet--checkpoint_idx-0-seed-1--230117_084826),
#  JobResult(/system/user/beck/pwbeck/projects/regularization/erank/outputs/IA-B-cifar10-15.1.0-lenet--230117_084806/outputs/IA-B-cifar10-15.1.0-lenet--checkpoint_idx-100-seed-1--230117_090107),
#  JobResult(/system/user/beck/pwbeck/projects/regularization/erank/outputs/IA-B-cifar10-15.1.0-lenet--230117_084806/outputs/IA-B-cifar10-15.1.0-lenet--checkpoint_idx-1000-seed-1--230117_090213),
#  JobResult(/system/user/beck/pwbeck/projects/regularization/erank/outputs/IA-B-cifar10-15.1.0-lenet--230117_084806/outputs/IA-B-cifar10-15.1.0-lenet--checkpoint_idx-10000-seed-1--230117_091712),
#  JobResult(/system/user/beck/pwbeck/projects/regularization/erank/outputs/IA-B-cifar10-15.1.0-lenet--230117_084806/outputs/IA-B-cifar10-15.1.0-lenet--checkpoint_idx-15000-seed-1--230117_090203),
#  JobResult(/system/user/beck/pwbeck/projects/regularization/erank/outputs/IA-B-cifar10-15.1.0-lenet--230117_084806/outputs/IA-B-cifar10-15.1.0-lenet--checkpoint_idx-2000-seed-1--230117_091513),
#  JobResult(/system/user/beck/pwbeck/projects/regularization/erank/outputs/IA-B-cifar10-15.1.0-lenet--230117_084806/outputs/IA-B-cifar10-15.1.0-lenet--checkpoint_idx-250-seed-1--230117_090157),
#  JobResult(/system/user/beck/pwbeck/projects/regularization/erank/outputs/IA-B-cifar10-15.1.0-lenet--230117_084806/outputs/IA-B-cifar10-15.1.0-lenet--checkpoint_idx-50-seed-1--230117_091727),
#  JobResult(/system/user/beck/pwbeck/projects/regularization/erank/outputs/IA-B-cifar10-15.1.0-lenet--230117_084806/outputs/IA-B-cifar10-15.1.0-lenet--checkpoint_idx-500-seed-1--230117_091352),
#  JobResult(/system/user/beck/pwbeck/projects/regularization/erank/outputs/IA-B-cifar10-15.1.0-lenet--230117_084806/outputs/IA-B-cifar10-15.1.0-lenet--checkpoint_idx-5000-seed-1--230117_090220)]
